# %%
import matplotlib.pyplot as plt
import math
import numpy as np  
import operator  
import time

# %%
import pickle
def load():
    with open("mnist.pkl",'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]

# %%
def one_hot_encoder(labels, class_nums=10):
    one_hot=np.zeros([len(labels), class_nums])
    for i in range(len(labels)):
        one_hot[i][labels[i]] = 1
    return one_hot

# %%
x_train, y_train, x_test, y_test = load()

# %%
y_train_one_hot = one_hot_encoder(y_train)
y_test_one_hot = one_hot_encoder(y_test)

# %%
def relu(x):
    return np.maximum(x,0.0)
 
def softmax(x):
    exps = np.exp(x - np.max(x))
    return exps / np.sum(exps)
 
def d_relu(x):
    (len_x,len_y)=x.shape
    d_x = np.zeros([len_x,len_y])
    [inds_x,inds_y]=np.where(x>=0)
    inds = np.stack((inds_x,inds_y), axis=-1) 
    for ind in inds:
        d_x[ind[0],ind[1]] = 1
    return d_x

# %%
# features=[]
# for data in train_data:
#     data=data.reshape(1,-1)
#     features.append(data)
# features = np.array(features).squeeze()
# labels = train_labels

# train_test_split = np.random.rand(len(features)) < 0.70
# train_x = features[train_test_split]
# train_y = labels[train_test_split]
# test_x = features[~train_test_split]
# test_y = labels[~train_test_split]
# print(train_test_split)

def next_batch(train_x, train_y, batch_size):
    batch_x = []
    batch_y = []
    rand_indices = []
    while len(rand_indices) != batch_size:
        tmp=np.random.randint(0,len(train_x) - 1)
        if tmp in rand_indices:
            continue
        else:
            rand_indices.append(tmp)
#     print("rand indices" , rand_indices)
    for index in rand_indices:
        batch_x.append(train_x[index])
        batch_y.append(train_y[index])
    return [np.array(batch_x), np.array(batch_y)]
#print(features.shape)

# %%
def initialize_variables(size):
    w=np.random.randn(size[0], size[1]) * 0.01
#     w=np.zeros([size[0], size[1]])
#     b=np.random.random([size[1]])
    b=np.zeros(size[1])
    return w,b

# %%
def cross_entropy(y_, y):
    y=np.argmax(y,axis=1)
    m=y.shape[0]
    p=softmax(y_)
    log_likelihood=-np.log(p[range(m),y])
    loss=np.sum(log_likelihood)/m
    return loss

# %%
learning_rate=0.01

def forward_propagation(w_1,b_1,w_2,b_2,w,b,X,y):
    Z1=np.dot(X,w_1) + b_1
    A1=relu(Z1)
    Z2=np.dot(A1,w_2) + b_2
    A2=relu(Z2)
    Z3=np.dot(A2,w) + b
    y_=softmax(Z3)
    
#     print(y)
#     print(y_)
#     y__sum=np.sum(y_,axis=1).reshape(-1,1)
#     y_=np.divide(y_,y__sum)
#     print(y__sum)
#     loss = -1/y.shape[1] * np.sum(y*np.log(y_) + (1-y)*np.log(1-y_))
    loss = np.square(y-y_).sum()
#     loss = cross_entropy(y_, y)
    cache={'Z1':Z1, 'A1':A1, 'Z2':Z2, 'A2':A2, 'Z3':Z3,'y_':y_}
    return cache, loss


def back_propagation(forward_cache,w_1,w_2,w,b_1,b_2,b,x,y):
    dZ3 = forward_cache['y_']-y
    wT = np.transpose(w)
    dZ2 = np.dot(dZ3,wT)*d_relu(forward_cache['Z2'])
    
    w_2T=np.transpose(w_2)
    dZ1 = np.dot(dZ2,w_2T)*d_relu(forward_cache['Z1'])
    
    
    m = forward_cache['A2'].shape[1]
    A2T = np.transpose(forward_cache['A2'])
    dw = np.dot(A2T,dZ3)/m
    db = np.sum(dZ3, axis=1, keepdims= True)/m
    
    m = forward_cache['A1'].shape[1]
    A1T=np.transpose(forward_cache['A1'])
    dw_2=np.dot(A1T,dZ2)/m
    db_2 = np.sum(dZ3,axis=1, keepdims= True)/m
    
    
    xT = np.transpose(x)
    dw_1 = np.dot(xT,dZ1)/m
    db_1 = np.sum(dZ2, axis=1, keepdims= True)/m
    
    
    w_1=w_1-learning_rate*dw_1
    b_1=b_1-learning_rate*db_1
    
    w_2=w_2-learning_rate*dw_2
    b_2=b_2-learning_rate*db_2
    
    w=w-learning_rate*dw
    b=b-learning_rate*b
    
    return w_1,b_1,w_2,b_2,w,b

# %%
print(y_train_one_hot.shape)
# Out:
# (60000, 10)

# %%
num_hidden_untis_one=200
num_hidden_units_two=50
n_dim = x_train.shape[1]
# sd = 1/np.sqrt(n_dim)

# index=0
# X=np.array(features[index])
# y=np.array(train_labels[index])
# print(X)
# print(y)


w_1,b_1=initialize_variables([x_train.shape[1], num_hidden_untis_one])

w_2,b_2=initialize_variables([num_hidden_untis_one, num_hidden_units_two])

w,b=initialize_variables([num_hidden_units_two, y_train_one_hot.shape[1]])

# learning rate, max iteration
num_epochs = 60000

for step in range(num_epochs):
    batch = next_batch(x_train, y_train_one_hot, 10)
    input_x = batch[0]
    y=batch[1]
#     input_x=x_train
#     y=y_train_one_hot
    forward_cache,loss = forward_propagation(w_1,b_1,w_2,b_2,w,b,input_x, y)
    
    if step % 10 == 0:
        print('step:',step)
#         print(forward_cache['y_'])
#         print(y)
        argmax_y=np.argmax(y,axis=1)
        argmax_y_=np.argmax(forward_cache['y_'],axis=1)
        equals=[]
        for i in range(len(argmax_y)):
            if argmax_y[i]==argmax_y_[i]:
                equals.append(1)
            else:
                equals.append(0)
        accuracy=np.sum(equals)/len(equals)
        print ("The loss is %f" % (np.mean(np.square(loss))))
        print ("The accuracy is %f\n" % accuracy)
        
        #print output_error.tolist()
#         continue
    w_1,b_1,w_2,b_2,w,b=back_propagation(forward_cache,w_1,w_2,w,b_1,b_2,b,input_x,y)
# Out:
# step: 0
# The loss is 96.105302
# The accuracy is 0.200000
#
# step: 10
# The loss is 95.760560
# The accuracy is 0.200000
#
# step: 20
# The loss is 95.641027
# The accuracy is 0.100000
#
# step: 30
# The loss is 82.453018
# The accuracy is 0.100000
#
# step: 40
# The loss is 119.829341
# The accuracy is 0.200000
#
# step: 50
# The loss is 121.000000
# The accuracy is 0.000000
#
# step: 60
# The loss is nan
# The accuracy is 0.200000
#
# step: 70
# The loss is nan
# The accuracy is 0.200000
#
# step: 80
# The loss is nan
# The accuracy is 0.100000
#
# step: 90
# The loss is nan
# The accuracy is 0.100000
#
# step: 100
# The loss is nan
# The accuracy is 0.000000
#
# step: 110
# The loss is nan
# The accuracy is 0.200000
#
# step: 120
# The loss is nan
# The accuracy is 0.200000
#
# step: 130
# The loss is nan
# The accuracy is 0.400000
#
# step: 140
# The loss is nan
# The accuracy is 0.100000
#
# step: 150
# The loss is nan
# The accuracy is 0.100000
#
# step: 160
# The loss is nan
# The accuracy is 0.000000
#
# step: 170
# The loss is nan
# The accuracy is 0.000000
#
# step: 180
# The loss is nan
# The accuracy is 0.300000
# /home/xin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in subtract
#   """
# /home/xin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in maximum
#
# /home/xin/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /home/xin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in greater_equal
#   # This is added back by InteractiveShellApp.init_path()
# step: 190
# The loss is nan
# The accuracy is 0.100000
#
# step: 200
# The loss is nan
# The accuracy is 0.100000
#
# step: 210
# The loss is nan
# The accuracy is 0.200000
#
# step: 220
# The loss is nan
# The accuracy is 0.000000
#
# step: 230
# The loss is nan
# The accuracy is 0.000000
#
# step: 240
# The loss is nan
# The accuracy is 0.000000
#
# step: 250
# The loss is nan
# The accuracy is 0.000000
#
# step: 260
# The loss is nan
# The accuracy is 0.000000
#
# step: 270
# The loss is nan
# The accuracy is 0.000000
#
# step: 280
# The loss is nan
# The accuracy is 0.200000
#
# step: 290
# The loss is nan
# The accuracy is 0.100000
#
# step: 300
# The loss is nan
# The accuracy is 0.100000
#
# step: 310
# The loss is nan
# The accuracy is 0.100000
#
# step: 320
# The loss is nan
# The accuracy is 0.100000
#
# step: 330
# The loss is nan
# The accuracy is 0.100000
#
# step: 340
# The loss is nan
# The accuracy is 0.100000
#
# step: 350
# The loss is nan
# The accuracy is 0.100000
#
# step: 360
# The loss is nan
# The accuracy is 0.000000
#
# step: 370
# The loss is nan
# The accuracy is 0.200000
#
# step: 380
# The loss is nan
# The accuracy is 0.100000
#
# step: 390
# The loss is nan
# The accuracy is 0.000000
#
# step: 400
# The loss is nan
# The accuracy is 0.000000
#
# step: 410
# The loss is nan
# The accuracy is 0.400000
#
# step: 420
# The loss is nan
# The accuracy is 0.100000
#
# step: 430
# The loss is nan
# The accuracy is 0.100000
#
# step: 440
# The loss is nan
# The accuracy is 0.100000
#
# step: 450
# The loss is nan
# The accuracy is 0.100000
#
# step: 460
# The loss is nan
# The accuracy is 0.000000
#
# step: 470
# The loss is nan
# The accuracy is 0.000000
#
# step: 480
# The loss is nan
# The accuracy is 0.300000
#
# step: 490
# The loss is nan
# The accuracy is 0.200000
#
# step: 500
# The loss is nan
# The accuracy is 0.100000
#
# step: 510
# The loss is nan
# The accuracy is 0.000000
#
# step: 520
# The loss is nan
# The accuracy is 0.000000
#
# step: 530
# The loss is nan
# The accuracy is 0.200000
#
# step: 540
# The loss is nan
# The accuracy is 0.200000
#
# step: 550
# The loss is nan
# The accuracy is 0.100000
#
# step: 560
# The loss is nan
# The accuracy is 0.100000
#
# step: 570
# The loss is nan
# The accuracy is 0.000000
#
# step: 580
# The loss is nan
# The accuracy is 0.200000
#
# step: 590
# The loss is nan
# The accuracy is 0.200000
#
# step: 600
# The loss is nan
# The accuracy is 0.100000
#
# step: 610
# The loss is nan
# The accuracy is 0.000000
#
# step: 620
# The loss is nan
# The accuracy is 0.000000
#
# step: 630
# The loss is nan
# The accuracy is 0.000000
#
# step: 640
# The loss is nan
# The accuracy is 0.300000
#
# step: 650
# The loss is nan
# The accuracy is 0.000000
#
# step: 660
# The loss is nan
# The accuracy is 0.100000
#
# step: 670
# The loss is nan
# The accuracy is 0.000000
#
# step: 680
# The loss is nan
# The accuracy is 0.000000
#
# step: 690
# The loss is nan
# The accuracy is 0.100000
#
# step: 700
# The loss is nan
# The accuracy is 0.100000
#
# step: 710
# The loss is nan
# The accuracy is 0.000000
#
# step: 720
# The loss is nan
# The accuracy is 0.200000
#
# step: 730
# The loss is nan
# The accuracy is 0.400000
#
# step: 740
# The loss is nan
# The accuracy is 0.300000
#
# step: 750
# The loss is nan
# The accuracy is 0.100000
#
# step: 760
# The loss is nan
# The accuracy is 0.200000
#
# step: 770
# The loss is nan
# The accuracy is 0.300000
#
# step: 780
# The loss is nan
# The accuracy is 0.100000
#
# step: 790
# The loss is nan
# The accuracy is 0.000000
#
# step: 800
# The loss is nan
# The accuracy is 0.000000
#
# step: 810
# The loss is nan
# The accuracy is 0.200000
#
# step: 820
# The loss is nan
# The accuracy is 0.300000
#
# step: 830
# The loss is nan
# The accuracy is 0.200000
#
# step: 840
# The loss is nan
# The accuracy is 0.000000
#
# step: 850
# The loss is nan
# The accuracy is 0.200000
#
# step: 860
# The loss is nan
# The accuracy is 0.100000
#
# step: 870
# The loss is nan
# The accuracy is 0.100000
#
# step: 880
# The loss is nan
# The accuracy is 0.200000
#
# step: 890
# The loss is nan
# The accuracy is 0.000000
#
# step: 900
# The loss is nan
# The accuracy is 0.100000
#
# step: 910
# The loss is nan
# The accuracy is 0.000000
#
# step: 920
# The loss is nan
# The accuracy is 0.100000
#
# step: 930
# The loss is nan
# The accuracy is 0.100000
#
# step: 940
# The loss is nan
# The accuracy is 0.100000
#
# step: 950
# The loss is nan
# The accuracy is 0.300000
#
# step: 960
# The loss is nan
# The accuracy is 0.200000
#
# step: 970
# The loss is nan
# The accuracy is 0.000000
#
# step: 980
# The loss is nan
# The accuracy is 0.200000
#
# step: 990
# The loss is nan
# The accuracy is 0.100000
#
# step: 1000
# The loss is nan
# The accuracy is 0.200000
#
# step: 1010
# The loss is nan
# The accuracy is 0.000000
#
# step: 1020
# The loss is nan
# The accuracy is 0.200000
#
# step: 1030
# The loss is nan
# The accuracy is 0.300000
#
# step: 1040
# The loss is nan
# The accuracy is 0.200000
#
# step: 1050
# The loss is nan
# The accuracy is 0.100000
#
# step: 1060
# The loss is nan
# The accuracy is 0.200000
#
# step: 1070
# The loss is nan
# The accuracy is 0.200000
#
# step: 1080
# The loss is nan
# The accuracy is 0.000000
#
# step: 1090
# The loss is nan
# The accuracy is 0.400000
#
# step: 1100
# The loss is nan
# The accuracy is 0.100000
#
# step: 1110
# The loss is nan
# The accuracy is 0.200000
#
# step: 1120
# The loss is nan
# The accuracy is 0.200000
#
# step: 1130
# The loss is nan
# The accuracy is 0.000000
#
# step: 1140
# The loss is nan
# The accuracy is 0.100000
#
# step: 1150
# The loss is nan
# The accuracy is 0.100000
#
# step: 1160
# The loss is nan
# The accuracy is 0.200000
#
# step: 1170
# The loss is nan
# The accuracy is 0.100000
#
# step: 1180
# The loss is nan
# The accuracy is 0.000000
#
# step: 1190
# The loss is nan
# The accuracy is 0.100000
#
# step: 1200
# The loss is nan
# The accuracy is 0.300000
#
# step: 1210
# The loss is nan
# The accuracy is 0.100000
#
# step: 1220
# The loss is nan
# The accuracy is 0.100000
#
# step: 1230
# The loss is nan
# The accuracy is 0.000000
#
# step: 1240
# The loss is nan
# The accuracy is 0.100000
#
# step: 1250
# The loss is nan
# The accuracy is 0.000000
#
# step: 1260
# The loss is nan
# The accuracy is 0.300000
#
# step: 1270
# The loss is nan
# The accuracy is 0.100000
#
# step: 1280
# The loss is nan
# The accuracy is 0.300000
#
# step: 1290
# The loss is nan
# The accuracy is 0.200000
#
# step: 1300
# The loss is nan
# The accuracy is 0.000000
#
# step: 1310
# The loss is nan
# The accuracy is 0.000000
#
# step: 1320
# The loss is nan
# The accuracy is 0.200000
#
# step: 1330
# The loss is nan
# The accuracy is 0.100000
#
# step: 1340
# The loss is nan
# The accuracy is 0.300000
#
# step: 1350
# The loss is nan
# The accuracy is 0.100000
#
# step: 1360
# The loss is nan
# The accuracy is 0.000000
#
# step: 1370
# The loss is nan
# The accuracy is 0.100000
#
# step: 1380
# The loss is nan
# The accuracy is 0.200000
#
# step: 1390
# The loss is nan
# The accuracy is 0.100000
#
# step: 1400
# The loss is nan
# The accuracy is 0.000000
#
# step: 1410
# The loss is nan
# The accuracy is 0.200000
#
# step: 1420
# The loss is nan
# The accuracy is 0.200000
#
# step: 1430
# The loss is nan
# The accuracy is 0.200000
#
# step: 1440
# The loss is nan
# The accuracy is 0.000000
#
# step: 1450
# The loss is nan
# The accuracy is 0.100000
#
# step: 1460
# The loss is nan
# The accuracy is 0.000000
#
# step: 1470
# The loss is nan
# The accuracy is 0.100000
#
# step: 1480
# The loss is nan
# The accuracy is 0.000000
#
# step: 1490
# The loss is nan
# The accuracy is 0.200000
#
# step: 1500
# The loss is nan
# The accuracy is 0.000000
#
# step: 1510
# The loss is nan
# The accuracy is 0.300000
#
# step: 1520
# The loss is nan
# The accuracy is 0.000000
#
# step: 1530
# The loss is nan
# The accuracy is 0.000000
#
# step: 1540
# The loss is nan
# The accuracy is 0.000000
#
# step: 1550
# The loss is nan
# The accuracy is 0.000000
#
# step: 1560
# The loss is nan
# The accuracy is 0.200000
#
# step: 1570
# The loss is nan
# The accuracy is 0.200000
#
# step: 1580
# The loss is nan
# The accuracy is 0.100000
#
# step: 1590
# The loss is nan
# The accuracy is 0.100000
#
# step: 1600
# The loss is nan
# The accuracy is 0.200000
#
# step: 1610
# The loss is nan
# The accuracy is 0.000000
#
# step: 1620
# The loss is nan
# The accuracy is 0.100000
#
# step: 1630
# The loss is nan
# The accuracy is 0.100000
#
# step: 1640
# The loss is nan
# The accuracy is 0.200000
#
# step: 1650
# The loss is nan
# The accuracy is 0.200000
#
# step: 1660
# The loss is nan
# The accuracy is 0.000000
#
# step: 1670
# The loss is nan
# The accuracy is 0.100000
#
# step: 1680
# The loss is nan
# The accuracy is 0.200000
#
# step: 1690
# The loss is nan
# The accuracy is 0.100000
#
# step: 1700
# The loss is nan
# The accuracy is 0.000000
#
# step: 1710
# The loss is nan
# The accuracy is 0.000000
#
# step: 1720
# The loss is nan
# The accuracy is 0.200000
#
# step: 1730
# The loss is nan
# The accuracy is 0.100000
#
# step: 1740
# The loss is nan
# The accuracy is 0.000000
#
# step: 1750
# The loss is nan
# The accuracy is 0.100000
#
# step: 1760
# The loss is nan
# The accuracy is 0.100000
#
# step: 1770
# The loss is nan
# The accuracy is 0.100000
#
# step: 1780
# The loss is nan
# The accuracy is 0.000000
#
# step: 1790
# The loss is nan
# The accuracy is 0.200000
#
# step: 1800
# The loss is nan
# The accuracy is 0.100000
#
# step: 1810
# The loss is nan
# The accuracy is 0.200000
#
# step: 1820
# The loss is nan
# The accuracy is 0.000000
#
# step: 1830
# The loss is nan
# The accuracy is 0.100000
#
# step: 1840
# The loss is nan
# The accuracy is 0.200000
#
# step: 1850
# The loss is nan
# The accuracy is 0.200000
#
# step: 1860
# The loss is nan
# The accuracy is 0.000000
#
# step: 1870
# The loss is nan
# The accuracy is 0.100000
#
# step: 1880
# The loss is nan
# The accuracy is 0.100000
#
# step: 1890
# The loss is nan
# The accuracy is 0.200000
# step: 1900
# The loss is nan
# The accuracy is 0.000000
#
# step: 1910
# The loss is nan
# The accuracy is 0.100000
#
# step: 1920
# The loss is nan
# The accuracy is 0.200000
#
# step: 1930
# The loss is nan
# The accuracy is 0.000000
#
# step: 1940
# The loss is nan
# The accuracy is 0.200000
#
# step: 1950
# The loss is nan
# The accuracy is 0.000000
#
# step: 1960
# The loss is nan
# The accuracy is 0.100000
#
# step: 1970
# The loss is nan
# The accuracy is 0.000000
#
# step: 1980
# The loss is nan
# The accuracy is 0.200000
#
# step: 1990
# The loss is nan
# The accuracy is 0.100000
#
# step: 2000
# The loss is nan
# The accuracy is 0.300000
#
# step: 2010
# The loss is nan
# The accuracy is 0.100000
#
# step: 2020
# The loss is nan
# The accuracy is 0.100000
#
# step: 2030
# The loss is nan
# The accuracy is 0.300000
#
# step: 2040
# The loss is nan
# The accuracy is 0.000000
#
# step: 2050
# The loss is nan
# The accuracy is 0.100000
#
# step: 2060
# The loss is nan
# The accuracy is 0.000000
#
# step: 2070
# The loss is nan
# The accuracy is 0.000000
#
# step: 2080
# The loss is nan
# The accuracy is 0.100000
#
# step: 2090
# The loss is nan
# The accuracy is 0.000000
#
# step: 2100
# The loss is nan
# The accuracy is 0.100000
#
# step: 2110
# The loss is nan
# The accuracy is 0.000000
#
# step: 2120
# The loss is nan
# The accuracy is 0.000000
#
# step: 2130
# The loss is nan
# The accuracy is 0.000000
#
# step: 2140
# The loss is nan
# The accuracy is 0.000000
#
# step: 2150
# The loss is nan
# The accuracy is 0.100000
#
# step: 2160
# The loss is nan
# The accuracy is 0.200000
#
# step: 2170
# The loss is nan
# The accuracy is 0.000000
#
# step: 2180
# The loss is nan
# The accuracy is 0.100000
#
# step: 2190
# The loss is nan
# The accuracy is 0.000000
#
# step: 2200
# The loss is nan
# The accuracy is 0.100000
#
# step: 2210
# The loss is nan
# The accuracy is 0.200000
#
# step: 2220
# The loss is nan
# The accuracy is 0.200000
#
# step: 2230
# The loss is nan
# The accuracy is 0.100000
#
# step: 2240
# The loss is nan
# The accuracy is 0.000000
#
# step: 2250
# The loss is nan
# The accuracy is 0.200000
#
# step: 2260
# The loss is nan
# The accuracy is 0.000000
#
# step: 2270
# The loss is nan
# The accuracy is 0.000000
#
# step: 2280
# The loss is nan
# The accuracy is 0.000000
#
# step: 2290
# The loss is nan
# The accuracy is 0.100000
#
# step: 2300
# The loss is nan
# The accuracy is 0.200000
#
# step: 2310
# The loss is nan
# The accuracy is 0.200000
#
# step: 2320
# The loss is nan
# The accuracy is 0.200000
#
# step: 2330
# The loss is nan
# The accuracy is 0.200000
#
# step: 2340
# The loss is nan
# The accuracy is 0.000000
#
# step: 2350
# The loss is nan
# The accuracy is 0.000000
#
# step: 2360
# The loss is nan
# The accuracy is 0.000000
#
# step: 2370
# The loss is nan
# The accuracy is 0.100000
#
# step: 2380
# The loss is nan
# The accuracy is 0.200000
#
# step: 2390
# The loss is nan
# The accuracy is 0.000000
#
# step: 2400
# The loss is nan
# The accuracy is 0.100000
#
# step: 2410
# The loss is nan
# The accuracy is 0.000000
#
# step: 2420
# The loss is nan
# The accuracy is 0.000000
#
# step: 2430
# The loss is nan
# The accuracy is 0.100000
#
# step: 2440
# The loss is nan
# The accuracy is 0.100000
#
# step: 2450
# The loss is nan
# The accuracy is 0.200000
#
# step: 2460
# The loss is nan
# The accuracy is 0.200000
#
# step: 2470
# The loss is nan
# The accuracy is 0.100000
#
# step: 2480
# The loss is nan
# The accuracy is 0.000000
#
# step: 2490
# The loss is nan
# The accuracy is 0.300000
#
# step: 2500
# The loss is nan
# The accuracy is 0.400000
#
# step: 2510
# The loss is nan
# The accuracy is 0.000000
#
# step: 2520
# The loss is nan
# The accuracy is 0.200000
#
# step: 2530
# The loss is nan
# The accuracy is 0.100000
#
# step: 2540
# The loss is nan
# The accuracy is 0.000000
#
# step: 2550
# The loss is nan
# The accuracy is 0.000000
#
# step: 2560
# The loss is nan
# The accuracy is 0.000000
#
# step: 2570
# The loss is nan
# The accuracy is 0.400000
#
# step: 2580
# The loss is nan
# The accuracy is 0.100000
#
# step: 2590
# The loss is nan
# The accuracy is 0.300000
#
# step: 2600
# The loss is nan
# The accuracy is 0.000000
#
# step: 2610
# The loss is nan
# The accuracy is 0.200000
#
# step: 2620
# The loss is nan
# The accuracy is 0.100000
#
# step: 2630
# The loss is nan
# The accuracy is 0.300000
#
# step: 2640
# The loss is nan
# The accuracy is 0.100000
#
# step: 2650
# The loss is nan
# The accuracy is 0.000000
#
# step: 2660
# The loss is nan
# The accuracy is 0.000000
#
# step: 2670
# The loss is nan
# The accuracy is 0.000000
#
# step: 2680
# The loss is nan
# The accuracy is 0.100000
#
# step: 2690
# The loss is nan
# The accuracy is 0.300000
#
# step: 2700
# The loss is nan
# The accuracy is 0.200000
#
# step: 2710
# The loss is nan
# The accuracy is 0.200000
#
# step: 2720
# The loss is nan
# The accuracy is 0.100000
#
# step: 2730
# The loss is nan
# The accuracy is 0.000000
#
# step: 2740
# The loss is nan
# The accuracy is 0.300000
#
# step: 2750
# The loss is nan
# The accuracy is 0.300000
#
# step: 2760
# The loss is nan
# The accuracy is 0.200000
#
# step: 2770
# The loss is nan
# The accuracy is 0.200000
#
# step: 2780
# The loss is nan
# The accuracy is 0.000000
#
# step: 2790
# The loss is nan
# The accuracy is 0.100000
#
# step: 2800
# The loss is nan
# The accuracy is 0.200000
#
# step: 2810
# The loss is nan
# The accuracy is 0.100000
#
# step: 2820
# The loss is nan
# The accuracy is 0.200000
#
# step: 2830
# The loss is nan
# The accuracy is 0.000000
#
# step: 2840
# The loss is nan
# The accuracy is 0.000000
#
# step: 2850
# The loss is nan
# The accuracy is 0.000000
#
# step: 2860
# The loss is nan
# The accuracy is 0.000000
#
# step: 2870
# The loss is nan
# The accuracy is 0.000000
#
# step: 2880
# The loss is nan
# The accuracy is 0.000000
#
# step: 2890
# The loss is nan
# The accuracy is 0.100000
#
# step: 2900
# The loss is nan
# The accuracy is 0.200000
#
# step: 2910
# The loss is nan
# The accuracy is 0.100000
#
# step: 2920
# The loss is nan
# The accuracy is 0.100000
#
# step: 2930
# The loss is nan
# The accuracy is 0.200000
#
# step: 2940
# The loss is nan
# The accuracy is 0.100000
#
# step: 2950
# The loss is nan
# The accuracy is 0.000000
#
# step: 2960
# The loss is nan
# The accuracy is 0.200000
#
# step: 2970
# The loss is nan
# The accuracy is 0.100000
#
# step: 2980
# The loss is nan
# The accuracy is 0.000000
#
# step: 2990
# The loss is nan
# The accuracy is 0.200000
#
# step: 3000
# The loss is nan
# The accuracy is 0.000000
#
# step: 3010
# The loss is nan
# The accuracy is 0.400000
#
# step: 3020
# The loss is nan
# The accuracy is 0.300000
#
# step: 3030
# The loss is nan
# The accuracy is 0.000000
#
# step: 3040
# The loss is nan
# The accuracy is 0.100000
#
# step: 3050
# The loss is nan
# The accuracy is 0.100000
#
# step: 3060
# The loss is nan
# The accuracy is 0.000000
#
# step: 3070
# The loss is nan
# The accuracy is 0.000000
#
# step: 3080
# The loss is nan
# The accuracy is 0.300000
#
# step: 3090
# The loss is nan
# The accuracy is 0.000000
#
# step: 3100
# The loss is nan
# The accuracy is 0.200000
#
# step: 3110
# The loss is nan
# The accuracy is 0.200000
#
# step: 3120
# The loss is nan
# The accuracy is 0.100000
#
# step: 3130
# The loss is nan
# The accuracy is 0.100000
#
# step: 3140
# The loss is nan
# The accuracy is 0.000000
#
# step: 3150
# The loss is nan
# The accuracy is 0.300000
#
# step: 3160
# The loss is nan
# The accuracy is 0.000000
#
# step: 3170
# The loss is nan
# The accuracy is 0.000000
#
# step: 3180
# The loss is nan
# The accuracy is 0.000000
#
# step: 3190
# The loss is nan
# The accuracy is 0.400000
#
# step: 3200
# The loss is nan
# The accuracy is 0.100000
#
# step: 3210
# The loss is nan
# The accuracy is 0.000000
#
# step: 3220
# The loss is nan
# The accuracy is 0.200000
#
# step: 3230
# The loss is nan
# The accuracy is 0.300000
#
# step: 3240
# The loss is nan
# The accuracy is 0.100000
#
# step: 3250
# The loss is nan
# The accuracy is 0.000000
#
# step: 3260
# The loss is nan
# The accuracy is 0.200000
#
# step: 3270
# The loss is nan
# The accuracy is 0.100000
#
# step: 3280
# The loss is nan
# The accuracy is 0.000000
#
# step: 3290
# The loss is nan
# The accuracy is 0.100000
#
# step: 3300
# The loss is nan
# The accuracy is 0.000000
#
# step: 3310
# The loss is nan
# The accuracy is 0.200000
#
# step: 3320
# The loss is nan
# The accuracy is 0.200000
#
# step: 3330
# The loss is nan
# The accuracy is 0.200000
#
# step: 3340
# The loss is nan
# The accuracy is 0.100000
#
# step: 3350
# The loss is nan
# The accuracy is 0.000000
#
# step: 3360
# The loss is nan
# The accuracy is 0.100000
#
# step: 3370
# The loss is nan
# The accuracy is 0.100000
#
# step: 3380
# The loss is nan
# The accuracy is 0.000000
#
# step: 3390
# The loss is nan
# The accuracy is 0.100000
#
# step: 3400
# The loss is nan
# The accuracy is 0.100000
#
# step: 3410
# The loss is nan
# The accuracy is 0.000000
#
# step: 3420
# The loss is nan
# The accuracy is 0.000000
#
# step: 3430
# The loss is nan
# The accuracy is 0.000000
#
# step: 3440
# The loss is nan
# The accuracy is 0.100000
#
# step: 3450
# The loss is nan
# The accuracy is 0.200000
#
# step: 3460
# The loss is nan
# The accuracy is 0.000000
#
# step: 3470
# The loss is nan
# The accuracy is 0.000000
# step: 3480
# The loss is nan
# The accuracy is 0.000000
#
# step: 3490
# The loss is nan
# The accuracy is 0.100000
#
# step: 3500
# The loss is nan
# The accuracy is 0.300000
#
# step: 3510
# The loss is nan
# The accuracy is 0.000000
#
# step: 3520
# The loss is nan
# The accuracy is 0.200000
#
# step: 3530
# The loss is nan
# The accuracy is 0.100000
#
# step: 3540
# The loss is nan
# The accuracy is 0.000000
#
# step: 3550
# The loss is nan
# The accuracy is 0.000000
#
# step: 3560
# The loss is nan
# The accuracy is 0.000000
#
# step: 3570
# The loss is nan
# The accuracy is 0.100000
#
# step: 3580
# The loss is nan
# The accuracy is 0.000000
#
# step: 3590
# The loss is nan
# The accuracy is 0.200000
#
# step: 3600
# The loss is nan
# The accuracy is 0.100000
#
# step: 3610
# The loss is nan
# The accuracy is 0.100000
#
# step: 3620
# The loss is nan
# The accuracy is 0.200000
#
# step: 3630
# The loss is nan
# The accuracy is 0.200000
#
# step: 3640
# The loss is nan
# The accuracy is 0.000000
#
# step: 3650
# The loss is nan
# The accuracy is 0.000000
#
# step: 3660
# The loss is nan
# The accuracy is 0.000000
#
# step: 3670
# The loss is nan
# The accuracy is 0.000000
#
# step: 3680
# The loss is nan
# The accuracy is 0.300000
#
# step: 3690
# The loss is nan
# The accuracy is 0.100000
#
# step: 3700
# The loss is nan
# The accuracy is 0.100000
#
# step: 3710
# The loss is nan
# The accuracy is 0.100000
#
# step: 3720
# The loss is nan
# The accuracy is 0.200000
#
# step: 3730
# The loss is nan
# The accuracy is 0.200000
#
# step: 3740
# The loss is nan
# The accuracy is 0.100000
#
# step: 3750
# The loss is nan
# The accuracy is 0.100000
#
# step: 3760
# The loss is nan
# The accuracy is 0.100000
#
# step: 3770
# The loss is nan
# The accuracy is 0.300000
#
# step: 3780
# The loss is nan
# The accuracy is 0.000000
#
# step: 3790
# The loss is nan
# The accuracy is 0.000000
#
# step: 3800
# The loss is nan
# The accuracy is 0.100000
#
# step: 3810
# The loss is nan
# The accuracy is 0.100000
#
# step: 3820
# The loss is nan
# The accuracy is 0.200000
#
# step: 3830
# The loss is nan
# The accuracy is 0.100000
#
# step: 3840
# The loss is nan
# The accuracy is 0.000000
#
# step: 3850
# The loss is nan
# The accuracy is 0.000000
#
# step: 3860
# The loss is nan
# The accuracy is 0.000000
#
# step: 3870
# The loss is nan
# The accuracy is 0.000000
#
# step: 3880
# The loss is nan
# The accuracy is 0.000000
#
# step: 3890
# The loss is nan
# The accuracy is 0.000000
#
# step: 3900
# The loss is nan
# The accuracy is 0.100000
#
# step: 3910
# The loss is nan
# The accuracy is 0.000000
#
# step: 3920
# The loss is nan
# The accuracy is 0.000000
#
# step: 3930
# The loss is nan
# The accuracy is 0.200000
#
# step: 3940
# The loss is nan
# The accuracy is 0.000000
#
# step: 3950
# The loss is nan
# The accuracy is 0.300000
#
# step: 3960
# The loss is nan
# The accuracy is 0.000000
#
# step: 3970
# The loss is nan
# The accuracy is 0.200000
#
# step: 3980
# The loss is nan
# The accuracy is 0.100000
#
# step: 3990
# The loss is nan
# The accuracy is 0.000000
#
# step: 4000
# The loss is nan
# The accuracy is 0.000000
#
# step: 4010
# The loss is nan
# The accuracy is 0.100000
#
# step: 4020
# The loss is nan
# The accuracy is 0.000000
#
# step: 4030
# The loss is nan
# The accuracy is 0.200000
#
# step: 4040
# The loss is nan
# The accuracy is 0.000000
#
# step: 4050
# The loss is nan
# The accuracy is 0.100000
#
# step: 4060
# The loss is nan
# The accuracy is 0.000000
#
# step: 4070
# The loss is nan
# The accuracy is 0.200000
#
# step: 4080
# The loss is nan
# The accuracy is 0.200000
#
# step: 4090
# The loss is nan
# The accuracy is 0.000000
#
# step: 4100
# The loss is nan
# The accuracy is 0.000000
#
# step: 4110
# The loss is nan
# The accuracy is 0.200000
#
# step: 4120
# The loss is nan
# The accuracy is 0.000000
#
# step: 4130
# The loss is nan
# The accuracy is 0.000000
#
# step: 4140
# The loss is nan
# The accuracy is 0.200000
#
# step: 4150
# The loss is nan
# The accuracy is 0.100000
#
# step: 4160
# The loss is nan
# The accuracy is 0.000000
#
# step: 4170
# The loss is nan
# The accuracy is 0.200000
#
# step: 4180
# The loss is nan
# The accuracy is 0.000000
#
# step: 4190
# The loss is nan
# The accuracy is 0.100000
#
# step: 4200
# The loss is nan
# The accuracy is 0.200000
#
# step: 4210
# The loss is nan
# The accuracy is 0.100000
#
# step: 4220
# The loss is nan
# The accuracy is 0.100000
#
# step: 4230
# The loss is nan
# The accuracy is 0.000000
#
# step: 4240
# The loss is nan
# The accuracy is 0.200000
#
# step: 4250
# The loss is nan
# The accuracy is 0.000000
#
# step: 4260
# The loss is nan
# The accuracy is 0.000000
#
# step: 4270
# The loss is nan
# The accuracy is 0.000000
#
# step: 4280
# The loss is nan
# The accuracy is 0.200000
#
# step: 4290
# The loss is nan
# The accuracy is 0.200000
#
# step: 4300
# The loss is nan
# The accuracy is 0.100000
#
# step: 4310
# The loss is nan
# The accuracy is 0.100000
#
# step: 4320
# The loss is nan
# The accuracy is 0.100000
#
# step: 4330
# The loss is nan
# The accuracy is 0.000000
#
# step: 4340
# The loss is nan
# The accuracy is 0.000000
#
# step: 4350
# The loss is nan
# The accuracy is 0.100000
#
# step: 4360
# The loss is nan
# The accuracy is 0.100000
#
# step: 4370
# The loss is nan
# The accuracy is 0.000000
#
# step: 4380
# The loss is nan
# The accuracy is 0.100000
#
# step: 4390
# The loss is nan
# The accuracy is 0.000000
#
# step: 4400
# The loss is nan
# The accuracy is 0.000000
#
# step: 4410
# The loss is nan
# The accuracy is 0.500000
#
# step: 4420
# The loss is nan
# The accuracy is 0.200000
#
# step: 4430
# The loss is nan
# The accuracy is 0.100000
#
# step: 4440
# The loss is nan
# The accuracy is 0.100000
#
# step: 4450
# The loss is nan
# The accuracy is 0.100000
#
# step: 4460
# The loss is nan
# The accuracy is 0.000000
#
# step: 4470
# The loss is nan
# The accuracy is 0.200000
#
# step: 4480
# The loss is nan
# The accuracy is 0.100000
#
# step: 4490
# The loss is nan
# The accuracy is 0.200000
#
# step: 4500
# The loss is nan
# The accuracy is 0.100000
#
# step: 4510
# The loss is nan
# The accuracy is 0.200000
#
# step: 4520
# The loss is nan
# The accuracy is 0.000000
#
# step: 4530
# The loss is nan
# The accuracy is 0.100000
#
# step: 4540
# The loss is nan
# The accuracy is 0.000000
#
# step: 4550
# The loss is nan
# The accuracy is 0.200000
#
# step: 4560
# The loss is nan
# The accuracy is 0.100000
#
# step: 4570
# The loss is nan
# The accuracy is 0.100000
#
# step: 4580
# The loss is nan
# The accuracy is 0.000000
#
# step: 4590
# The loss is nan
# The accuracy is 0.000000
#
# step: 4600
# The loss is nan
# The accuracy is 0.100000
#
# step: 4610
# The loss is nan
# The accuracy is 0.000000
#
# step: 4620
# The loss is nan
# The accuracy is 0.200000
#
# step: 4630
# The loss is nan
# The accuracy is 0.000000
#
# step: 4640
# The loss is nan
# The accuracy is 0.100000
#
# step: 4650
# The loss is nan
# The accuracy is 0.000000
#
# step: 4660
# The loss is nan
# The accuracy is 0.200000
#
# step: 4670
# The loss is nan
# The accuracy is 0.100000
#
# step: 4680
# The loss is nan
# The accuracy is 0.100000
#
# step: 4690
# The loss is nan
# The accuracy is 0.200000
#
# step: 4700
# The loss is nan
# The accuracy is 0.400000
#
# step: 4710
# The loss is nan
# The accuracy is 0.300000
#
# step: 4720
# The loss is nan
# The accuracy is 0.000000
#
# step: 4730
# The loss is nan
# The accuracy is 0.000000
#
# step: 4740
# The loss is nan
# The accuracy is 0.000000
#
# step: 4750
# The loss is nan
# The accuracy is 0.300000
#
# step: 4760
# The loss is nan
# The accuracy is 0.000000
#
# step: 4770
# The loss is nan
# The accuracy is 0.000000
#
# step: 4780
# The loss is nan
# The accuracy is 0.100000
#
# step: 4790
# The loss is nan
# The accuracy is 0.100000
#
# step: 4800
# The loss is nan
# The accuracy is 0.200000
#
# step: 4810
# The loss is nan
# The accuracy is 0.000000
#
# step: 4820
# The loss is nan
# The accuracy is 0.200000
#
# step: 4830
# The loss is nan
# The accuracy is 0.000000
#
# step: 4840
# The loss is nan
# The accuracy is 0.100000
#
# step: 4850
# The loss is nan
# The accuracy is 0.200000
#
# step: 4860
# The loss is nan
# The accuracy is 0.100000
#
# step: 4870
# The loss is nan
# The accuracy is 0.000000
#
# step: 4880
# The loss is nan
# The accuracy is 0.000000
#
# step: 4890
# The loss is nan
# The accuracy is 0.100000
#
# step: 4900
# The loss is nan
# The accuracy is 0.200000
#
# step: 4910
# The loss is nan
# The accuracy is 0.000000
#
# step: 4920
# The loss is nan
# The accuracy is 0.000000
#
# step: 4930
# The loss is nan
# The accuracy is 0.100000
#
# step: 4940
# The loss is nan
# The accuracy is 0.000000
#
# step: 4950
# The loss is nan
# The accuracy is 0.100000
#
# step: 4960
# The loss is nan
# The accuracy is 0.000000
#
# step: 4970
# The loss is nan
# The accuracy is 0.000000
#
# step: 4980
# The loss is nan
# The accuracy is 0.100000
#
# step: 4990
# The loss is nan
# The accuracy is 0.000000
#
# step: 5000
# The loss is nan
# The accuracy is 0.100000
#
# step: 5010
# The loss is nan
# The accuracy is 0.000000
#
# step: 5020
# The loss is nan
# The accuracy is 0.100000
#
# step: 5030
# The loss is nan
# The accuracy is 0.100000
#
# step: 5040
# The loss is nan
# The accuracy is 0.100000
#
# step: 5050
# The loss is nan
# The accuracy is 0.200000
#
# step: 5060
# The loss is nan
# The accuracy is 0.000000
#
# step: 5070
# The loss is nan
# The accuracy is 0.100000
#
# step: 5080
# The loss is nan
# The accuracy is 0.000000
#
# step: 5090
# The loss is nan
# The accuracy is 0.000000
# step: 5100
# The loss is nan
# The accuracy is 0.000000
#
# step: 5110
# The loss is nan
# The accuracy is 0.000000
#
# step: 5120
# The loss is nan
# The accuracy is 0.100000
#
# step: 5130
# The loss is nan
# The accuracy is 0.200000
#
# step: 5140
# The loss is nan
# The accuracy is 0.000000
#
# step: 5150
# The loss is nan
# The accuracy is 0.200000
#
# step: 5160
# The loss is nan
# The accuracy is 0.100000
#
# step: 5170
# The loss is nan
# The accuracy is 0.100000
#
# step: 5180
# The loss is nan
# The accuracy is 0.200000
#
# step: 5190
# The loss is nan
# The accuracy is 0.200000
#
# step: 5200
# The loss is nan
# The accuracy is 0.100000
#
# step: 5210
# The loss is nan
# The accuracy is 0.100000
#
# step: 5220
# The loss is nan
# The accuracy is 0.000000
#
# step: 5230
# The loss is nan
# The accuracy is 0.200000
#
# step: 5240
# The loss is nan
# The accuracy is 0.000000
#
# step: 5250
# The loss is nan
# The accuracy is 0.000000
#
# step: 5260
# The loss is nan
# The accuracy is 0.100000
#
# step: 5270
# The loss is nan
# The accuracy is 0.100000
#
# step: 5280
# The loss is nan
# The accuracy is 0.100000
#
# step: 5290
# The loss is nan
# The accuracy is 0.100000
#
# step: 5300
# The loss is nan
# The accuracy is 0.100000
#
# step: 5310
# The loss is nan
# The accuracy is 0.200000
#
# step: 5320
# The loss is nan
# The accuracy is 0.000000
#
# step: 5330
# The loss is nan
# The accuracy is 0.300000
#
# step: 5340
# The loss is nan
# The accuracy is 0.200000
#
# step: 5350
# The loss is nan
# The accuracy is 0.100000
#
# step: 5360
# The loss is nan
# The accuracy is 0.100000
#
# step: 5370
# The loss is nan
# The accuracy is 0.000000
#
# step: 5380
# The loss is nan
# The accuracy is 0.200000
#
# step: 5390
# The loss is nan
# The accuracy is 0.100000
#
# step: 5400
# The loss is nan
# The accuracy is 0.300000
#
# step: 5410
# The loss is nan
# The accuracy is 0.100000
#
# step: 5420
# The loss is nan
# The accuracy is 0.100000
#
# step: 5430
# The loss is nan
# The accuracy is 0.000000
#
# step: 5440
# The loss is nan
# The accuracy is 0.100000
#
# step: 5450
# The loss is nan
# The accuracy is 0.000000
#
# step: 5460
# The loss is nan
# The accuracy is 0.000000
#
# step: 5470
# The loss is nan
# The accuracy is 0.100000
#
# step: 5480
# The loss is nan
# The accuracy is 0.000000
#
# step: 5490
# The loss is nan
# The accuracy is 0.200000
#
# step: 5500
# The loss is nan
# The accuracy is 0.100000
#
# step: 5510
# The loss is nan
# The accuracy is 0.100000
#
# step: 5520
# The loss is nan
# The accuracy is 0.000000
#
# step: 5530
# The loss is nan
# The accuracy is 0.000000
#
# step: 5540
# The loss is nan
# The accuracy is 0.100000
#
# step: 5550
# The loss is nan
# The accuracy is 0.000000
#
# step: 5560
# The loss is nan
# The accuracy is 0.100000
#
# step: 5570
# The loss is nan
# The accuracy is 0.100000
#
# step: 5580
# The loss is nan
# The accuracy is 0.400000
#
# step: 5590
# The loss is nan
# The accuracy is 0.000000
#
# step: 5600
# The loss is nan
# The accuracy is 0.200000
#
# step: 5610
# The loss is nan
# The accuracy is 0.000000
#
# step: 5620
# The loss is nan
# The accuracy is 0.200000
#
# step: 5630
# The loss is nan
# The accuracy is 0.100000
#
# step: 5640
# The loss is nan
# The accuracy is 0.100000
#
# step: 5650
# The loss is nan
# The accuracy is 0.100000
#
# step: 5660
# The loss is nan
# The accuracy is 0.100000
#
# step: 5670
# The loss is nan
# The accuracy is 0.000000
#
# step: 5680
# The loss is nan
# The accuracy is 0.100000
#
# step: 5690
# The loss is nan
# The accuracy is 0.100000
#
# step: 5700
# The loss is nan
# The accuracy is 0.200000
#
# step: 5710
# The loss is nan
# The accuracy is 0.000000
#
# step: 5720
# The loss is nan
# The accuracy is 0.000000
#
# step: 5730
# The loss is nan
# The accuracy is 0.100000
#
# step: 5740
# The loss is nan
# The accuracy is 0.400000
#
# step: 5750
# The loss is nan
# The accuracy is 0.100000
#
# step: 5760
# The loss is nan
# The accuracy is 0.000000
#
# step: 5770
# The loss is nan
# The accuracy is 0.000000
#
# step: 5780
# The loss is nan
# The accuracy is 0.100000
#
# step: 5790
# The loss is nan
# The accuracy is 0.100000
#
# step: 5800
# The loss is nan
# The accuracy is 0.000000
#
# step: 5810
# The loss is nan
# The accuracy is 0.200000
#
# step: 5820
# The loss is nan
# The accuracy is 0.200000
#
# step: 5830
# The loss is nan
# The accuracy is 0.100000
#
# step: 5840
# The loss is nan
# The accuracy is 0.100000
#
# step: 5850
# The loss is nan
# The accuracy is 0.100000
#
# step: 5860
# The loss is nan
# The accuracy is 0.200000
#
# step: 5870
# The loss is nan
# The accuracy is 0.000000
#
# step: 5880
# The loss is nan
# The accuracy is 0.200000
#
# step: 5890
# The loss is nan
# The accuracy is 0.000000
#
# step: 5900
# The loss is nan
# The accuracy is 0.200000
#
# step: 5910
# The loss is nan
# The accuracy is 0.300000
#
# step: 5920
# The loss is nan
# The accuracy is 0.000000
#
# step: 5930
# The loss is nan
# The accuracy is 0.100000
#
# step: 5940
# The loss is nan
# The accuracy is 0.100000
#
# step: 5950
# The loss is nan
# The accuracy is 0.200000
#
# step: 5960
# The loss is nan
# The accuracy is 0.100000
#
# step: 5970
# The loss is nan
# The accuracy is 0.200000
#
# step: 5980
# The loss is nan
# The accuracy is 0.000000
#
# step: 5990
# The loss is nan
# The accuracy is 0.200000
#
# step: 6000
# The loss is nan
# The accuracy is 0.100000
#
# step: 6010
# The loss is nan
# The accuracy is 0.100000
#
# step: 6020
# The loss is nan
# The accuracy is 0.000000
#
# step: 6030
# The loss is nan
# The accuracy is 0.100000
#
# step: 6040
# The loss is nan
# The accuracy is 0.100000
#
# step: 6050
# The loss is nan
# The accuracy is 0.000000
#
# step: 6060
# The loss is nan
# The accuracy is 0.000000
#
# step: 6070
# The loss is nan
# The accuracy is 0.000000
#
# step: 6080
# The loss is nan
# The accuracy is 0.000000
#
# step: 6090
# The loss is nan
# The accuracy is 0.200000
#
# step: 6100
# The loss is nan
# The accuracy is 0.100000
#
# step: 6110
# The loss is nan
# The accuracy is 0.000000
#
# step: 6120
# The loss is nan
# The accuracy is 0.100000
#
# step: 6130
# The loss is nan
# The accuracy is 0.000000
#
# step: 6140
# The loss is nan
# The accuracy is 0.100000
#
# step: 6150
# The loss is nan
# The accuracy is 0.100000
#
# step: 6160
# The loss is nan
# The accuracy is 0.000000
#
# step: 6170
# The loss is nan
# The accuracy is 0.300000
#
# step: 6180
# The loss is nan
# The accuracy is 0.000000
#
# step: 6190
# The loss is nan
# The accuracy is 0.000000
#
# step: 6200
# The loss is nan
# The accuracy is 0.200000
#
# step: 6210
# The loss is nan
# The accuracy is 0.300000
#
# step: 6220
# The loss is nan
# The accuracy is 0.300000
#
# step: 6230
# The loss is nan
# The accuracy is 0.100000
#
# step: 6240
# The loss is nan
# The accuracy is 0.000000
#
# step: 6250
# The loss is nan
# The accuracy is 0.200000
#
# step: 6260
# The loss is nan
# The accuracy is 0.100000
#
# step: 6270
# The loss is nan
# The accuracy is 0.000000
#
# step: 6280
# The loss is nan
# The accuracy is 0.100000
#
# step: 6290
# The loss is nan
# The accuracy is 0.300000
#
# step: 6300
# The loss is nan
# The accuracy is 0.100000
#
# step: 6310
# The loss is nan
# The accuracy is 0.000000
#
# step: 6320
# The loss is nan
# The accuracy is 0.000000
#
# step: 6330
# The loss is nan
# The accuracy is 0.100000
#
# step: 6340
# The loss is nan
# The accuracy is 0.200000
#
# step: 6350
# The loss is nan
# The accuracy is 0.000000
#
# step: 6360
# The loss is nan
# The accuracy is 0.300000
#
# step: 6370
# The loss is nan
# The accuracy is 0.100000
#
# step: 6380
# The loss is nan
# The accuracy is 0.000000
#
# step: 6390
# The loss is nan
# The accuracy is 0.100000
#
# step: 6400
# The loss is nan
# The accuracy is 0.200000
#
# step: 6410
# The loss is nan
# The accuracy is 0.100000
#
# step: 6420
# The loss is nan
# The accuracy is 0.100000
#
# step: 6430
# The loss is nan
# The accuracy is 0.100000
#
# step: 6440
# The loss is nan
# The accuracy is 0.300000
#
# step: 6450
# The loss is nan
# The accuracy is 0.300000
#
# step: 6460
# The loss is nan
# The accuracy is 0.100000
#
# step: 6470
# The loss is nan
# The accuracy is 0.100000
#
# step: 6480
# The loss is nan
# The accuracy is 0.000000
#
# step: 6490
# The loss is nan
# The accuracy is 0.000000
#
# step: 6500
# The loss is nan
# The accuracy is 0.200000
#
# step: 6510
# The loss is nan
# The accuracy is 0.100000
#
# step: 6520
# The loss is nan
# The accuracy is 0.100000
#
# step: 6530
# The loss is nan
# The accuracy is 0.000000
#
# step: 6540
# The loss is nan
# The accuracy is 0.000000
#
# step: 6550
# The loss is nan
# The accuracy is 0.100000
#
# step: 6560
# The loss is nan
# The accuracy is 0.000000
#
# step: 6570
# The loss is nan
# The accuracy is 0.300000
#
# step: 6580
# The loss is nan
# The accuracy is 0.200000
#
# step: 6590
# The loss is nan
# The accuracy is 0.100000
#
# step: 6600
# The loss is nan
# The accuracy is 0.100000
#
# step: 6610
# The loss is nan
# The accuracy is 0.000000
#
# step: 6620
# The loss is nan
# The accuracy is 0.100000
#
# step: 6630
# The loss is nan
# The accuracy is 0.200000
#
# step: 6640
# The loss is nan
# The accuracy is 0.000000
#
# step: 6650
# The loss is nan
# The accuracy is 0.000000
#
# step: 6660
# The loss is nan
# The accuracy is 0.000000
#
# step: 6670
# The loss is nan
# The accuracy is 0.100000
#
# step: 6680
# The loss is nan
# The accuracy is 0.200000
#
# step: 6690
# The loss is nan
# The accuracy is 0.300000
#
# step: 6700
# The loss is nan
# The accuracy is 0.100000
#
# step: 6710
# The loss is nan
# The accuracy is 0.200000
# step: 6720
# The loss is nan
# The accuracy is 0.100000
#
# step: 6730
# The loss is nan
# The accuracy is 0.100000
#
# step: 6740
# The loss is nan
# The accuracy is 0.100000
#
# step: 6750
# The loss is nan
# The accuracy is 0.000000
#
# step: 6760
# The loss is nan
# The accuracy is 0.200000
#
# step: 6770
# The loss is nan
# The accuracy is 0.000000
#
# step: 6780
# The loss is nan
# The accuracy is 0.000000
#
# step: 6790
# The loss is nan
# The accuracy is 0.100000
#
# step: 6800
# The loss is nan
# The accuracy is 0.100000
#
# step: 6810
# The loss is nan
# The accuracy is 0.200000
#
# step: 6820
# The loss is nan
# The accuracy is 0.100000
#
# step: 6830
# The loss is nan
# The accuracy is 0.000000
#
# step: 6840
# The loss is nan
# The accuracy is 0.100000
#
# step: 6850
# The loss is nan
# The accuracy is 0.300000
#
# step: 6860
# The loss is nan
# The accuracy is 0.100000
#
# step: 6870
# The loss is nan
# The accuracy is 0.000000
#
# step: 6880
# The loss is nan
# The accuracy is 0.100000
#
# step: 6890
# The loss is nan
# The accuracy is 0.000000
#
# step: 6900
# The loss is nan
# The accuracy is 0.000000
#
# step: 6910
# The loss is nan
# The accuracy is 0.100000
#
# step: 6920
# The loss is nan
# The accuracy is 0.100000
#
# step: 6930
# The loss is nan
# The accuracy is 0.100000
#
# step: 6940
# The loss is nan
# The accuracy is 0.000000
#
# step: 6950
# The loss is nan
# The accuracy is 0.200000
#
# step: 6960
# The loss is nan
# The accuracy is 0.200000
#
# step: 6970
# The loss is nan
# The accuracy is 0.300000
#
# step: 6980
# The loss is nan
# The accuracy is 0.200000
#
# step: 6990
# The loss is nan
# The accuracy is 0.000000
#
# step: 7000
# The loss is nan
# The accuracy is 0.000000
#
# step: 7010
# The loss is nan
# The accuracy is 0.100000
#
# step: 7020
# The loss is nan
# The accuracy is 0.000000
#
# step: 7030
# The loss is nan
# The accuracy is 0.200000
#
# step: 7040
# The loss is nan
# The accuracy is 0.000000
#
# step: 7050
# The loss is nan
# The accuracy is 0.100000
#
# step: 7060
# The loss is nan
# The accuracy is 0.000000
#
# step: 7070
# The loss is nan
# The accuracy is 0.200000
#
# step: 7080
# The loss is nan
# The accuracy is 0.000000
#
# step: 7090
# The loss is nan
# The accuracy is 0.200000
#
# step: 7100
# The loss is nan
# The accuracy is 0.100000
#
# step: 7110
# The loss is nan
# The accuracy is 0.000000
#
# step: 7120
# The loss is nan
# The accuracy is 0.000000
#
# step: 7130
# The loss is nan
# The accuracy is 0.100000
#
# step: 7140
# The loss is nan
# The accuracy is 0.000000
#
# step: 7150
# The loss is nan
# The accuracy is 0.300000
#
# step: 7160
# The loss is nan
# The accuracy is 0.100000
#
# step: 7170
# The loss is nan
# The accuracy is 0.000000
#
# step: 7180
# The loss is nan
# The accuracy is 0.000000
#
# step: 7190
# The loss is nan
# The accuracy is 0.100000
#
# step: 7200
# The loss is nan
# The accuracy is 0.100000
#
# step: 7210
# The loss is nan
# The accuracy is 0.100000
#
# step: 7220
# The loss is nan
# The accuracy is 0.000000
#
# step: 7230
# The loss is nan
# The accuracy is 0.000000
#
# step: 7240
# The loss is nan
# The accuracy is 0.000000
#
# step: 7250
# The loss is nan
# The accuracy is 0.100000
#
# step: 7260
# The loss is nan
# The accuracy is 0.200000
#
# step: 7270
# The loss is nan
# The accuracy is 0.200000
#
# step: 7280
# The loss is nan
# The accuracy is 0.200000
#
# step: 7290
# The loss is nan
# The accuracy is 0.000000
#
# step: 7300
# The loss is nan
# The accuracy is 0.100000
#
# step: 7310
# The loss is nan
# The accuracy is 0.000000
#
# step: 7320
# The loss is nan
# The accuracy is 0.000000
#
# step: 7330
# The loss is nan
# The accuracy is 0.200000
#
# step: 7340
# The loss is nan
# The accuracy is 0.200000
#
# step: 7350
# The loss is nan
# The accuracy is 0.000000
#
# step: 7360
# The loss is nan
# The accuracy is 0.000000
#
# step: 7370
# The loss is nan
# The accuracy is 0.100000
#
# step: 7380
# The loss is nan
# The accuracy is 0.300000
#
# step: 7390
# The loss is nan
# The accuracy is 0.100000
#
# step: 7400
# The loss is nan
# The accuracy is 0.300000
#
# step: 7410
# The loss is nan
# The accuracy is 0.100000
#
# step: 7420
# The loss is nan
# The accuracy is 0.100000
#
# step: 7430
# The loss is nan
# The accuracy is 0.200000
#
# step: 7440
# The loss is nan
# The accuracy is 0.300000
#
# step: 7450
# The loss is nan
# The accuracy is 0.000000
#
# step: 7460
# The loss is nan
# The accuracy is 0.100000
#
# step: 7470
# The loss is nan
# The accuracy is 0.000000
#
# step: 7480
# The loss is nan
# The accuracy is 0.000000
#
# step: 7490
# The loss is nan
# The accuracy is 0.000000
#
# step: 7500
# The loss is nan
# The accuracy is 0.000000
#
# step: 7510
# The loss is nan
# The accuracy is 0.200000
#
# step: 7520
# The loss is nan
# The accuracy is 0.000000
#
# step: 7530
# The loss is nan
# The accuracy is 0.000000
#
# step: 7540
# The loss is nan
# The accuracy is 0.000000
#
# step: 7550
# The loss is nan
# The accuracy is 0.000000
#
# step: 7560
# The loss is nan
# The accuracy is 0.000000
#
# step: 7570
# The loss is nan
# The accuracy is 0.100000
#
# step: 7580
# The loss is nan
# The accuracy is 0.000000
#
# step: 7590
# The loss is nan
# The accuracy is 0.100000
#
# step: 7600
# The loss is nan
# The accuracy is 0.100000
#
# step: 7610
# The loss is nan
# The accuracy is 0.100000
#
# step: 7620
# The loss is nan
# The accuracy is 0.100000
#
# step: 7630
# The loss is nan
# The accuracy is 0.100000
#
# step: 7640
# The loss is nan
# The accuracy is 0.000000
#
# step: 7650
# The loss is nan
# The accuracy is 0.100000
#
# step: 7660
# The loss is nan
# The accuracy is 0.200000
#
# step: 7670
# The loss is nan
# The accuracy is 0.100000
#
# step: 7680
# The loss is nan
# The accuracy is 0.100000
#
# step: 7690
# The loss is nan
# The accuracy is 0.100000
#
# step: 7700
# The loss is nan
# The accuracy is 0.200000
#
# step: 7710
# The loss is nan
# The accuracy is 0.100000
#
# step: 7720
# The loss is nan
# The accuracy is 0.000000
#
# step: 7730
# The loss is nan
# The accuracy is 0.000000
#
# step: 7740
# The loss is nan
# The accuracy is 0.100000
#
# step: 7750
# The loss is nan
# The accuracy is 0.100000
#
# step: 7760
# The loss is nan
# The accuracy is 0.000000
#
# step: 7770
# The loss is nan
# The accuracy is 0.000000
#
# step: 7780
# The loss is nan
# The accuracy is 0.000000
#
# step: 7790
# The loss is nan
# The accuracy is 0.000000
#
# step: 7800
# The loss is nan
# The accuracy is 0.100000
#
# step: 7810
# The loss is nan
# The accuracy is 0.100000
#
# step: 7820
# The loss is nan
# The accuracy is 0.000000
#
# step: 7830
# The loss is nan
# The accuracy is 0.200000
#
# step: 7840
# The loss is nan
# The accuracy is 0.100000
#
# step: 7850
# The loss is nan
# The accuracy is 0.100000
#
# step: 7860
# The loss is nan
# The accuracy is 0.000000
#
# step: 7870
# The loss is nan
# The accuracy is 0.100000
#
# step: 7880
# The loss is nan
# The accuracy is 0.000000
#
# step: 7890
# The loss is nan
# The accuracy is 0.100000
#
# step: 7900
# The loss is nan
# The accuracy is 0.200000
#
# step: 7910
# The loss is nan
# The accuracy is 0.000000
#
# step: 7920
# The loss is nan
# The accuracy is 0.200000
#
# step: 7930
# The loss is nan
# The accuracy is 0.100000
#
# step: 7940
# The loss is nan
# The accuracy is 0.100000
#
# step: 7950
# The loss is nan
# The accuracy is 0.000000
#
# step: 7960
# The loss is nan
# The accuracy is 0.100000
#
# step: 7970
# The loss is nan
# The accuracy is 0.300000
#
# step: 7980
# The loss is nan
# The accuracy is 0.000000
#
# step: 7990
# The loss is nan
# The accuracy is 0.200000
#
# step: 8000
# The loss is nan
# The accuracy is 0.100000
#
# step: 8010
# The loss is nan
# The accuracy is 0.000000
#
# step: 8020
# The loss is nan
# The accuracy is 0.100000
#
# step: 8030
# The loss is nan
# The accuracy is 0.100000
#
# step: 8040
# The loss is nan
# The accuracy is 0.200000
#
# step: 8050
# The loss is nan
# The accuracy is 0.100000
#
# step: 8060
# The loss is nan
# The accuracy is 0.100000
#
# step: 8070
# The loss is nan
# The accuracy is 0.000000
#
# step: 8080
# The loss is nan
# The accuracy is 0.100000
#
# step: 8090
# The loss is nan
# The accuracy is 0.000000
#
# step: 8100
# The loss is nan
# The accuracy is 0.000000
#
# step: 8110
# The loss is nan
# The accuracy is 0.100000
#
# step: 8120
# The loss is nan
# The accuracy is 0.100000
#
# step: 8130
# The loss is nan
# The accuracy is 0.200000
#
# step: 8140
# The loss is nan
# The accuracy is 0.100000
#
# step: 8150
# The loss is nan
# The accuracy is 0.100000
#
# step: 8160
# The loss is nan
# The accuracy is 0.000000
#
# step: 8170
# The loss is nan
# The accuracy is 0.000000
#
# step: 8180
# The loss is nan
# The accuracy is 0.100000
#
# step: 8190
# The loss is nan
# The accuracy is 0.000000
#
# step: 8200
# The loss is nan
# The accuracy is 0.100000
#
# step: 8210
# The loss is nan
# The accuracy is 0.100000
#
# step: 8220
# The loss is nan
# The accuracy is 0.100000
#
# step: 8230
# The loss is nan
# The accuracy is 0.100000
#
# step: 8240
# The loss is nan
# The accuracy is 0.200000
#
# step: 8250
# The loss is nan
# The accuracy is 0.000000
#
# step: 8260
# The loss is nan
# The accuracy is 0.100000
#
# step: 8270
# The loss is nan
# The accuracy is 0.100000
#
# step: 8280
# The loss is nan
# The accuracy is 0.000000
#
# step: 8290
# The loss is nan
# The accuracy is 0.000000
#
# step: 8300
# The loss is nan
# The accuracy is 0.100000
#
# step: 8310
# The loss is nan
# The accuracy is 0.000000
#
# step: 8320
# The loss is nan
# The accuracy is 0.000000
#
# step: 8330
# The loss is nan
# The accuracy is 0.100000
#
# step: 8340
# The loss is nan
# The accuracy is 0.200000
# step: 8350
# The loss is nan
# The accuracy is 0.100000
#
# step: 8360
# The loss is nan
# The accuracy is 0.100000
#
# step: 8370
# The loss is nan
# The accuracy is 0.300000
#
# step: 8380
# The loss is nan
# The accuracy is 0.100000
#
# step: 8390
# The loss is nan
# The accuracy is 0.000000
#
# step: 8400
# The loss is nan
# The accuracy is 0.000000
#
# step: 8410
# The loss is nan
# The accuracy is 0.000000
#
# step: 8420
# The loss is nan
# The accuracy is 0.100000
#
# step: 8430
# The loss is nan
# The accuracy is 0.000000
#
# step: 8440
# The loss is nan
# The accuracy is 0.000000
#
# step: 8450
# The loss is nan
# The accuracy is 0.100000
#
# step: 8460
# The loss is nan
# The accuracy is 0.000000
#
# step: 8470
# The loss is nan
# The accuracy is 0.000000
#
# step: 8480
# The loss is nan
# The accuracy is 0.400000
#
# step: 8490
# The loss is nan
# The accuracy is 0.000000
#
# step: 8500
# The loss is nan
# The accuracy is 0.000000
#
# step: 8510
# The loss is nan
# The accuracy is 0.100000
#
# step: 8520
# The loss is nan
# The accuracy is 0.000000
#
# step: 8530
# The loss is nan
# The accuracy is 0.100000
#
# step: 8540
# The loss is nan
# The accuracy is 0.100000
#
# step: 8550
# The loss is nan
# The accuracy is 0.000000
#
# step: 8560
# The loss is nan
# The accuracy is 0.000000
#
# step: 8570
# The loss is nan
# The accuracy is 0.100000
#
# step: 8580
# The loss is nan
# The accuracy is 0.100000
#
# step: 8590
# The loss is nan
# The accuracy is 0.200000
#
# step: 8600
# The loss is nan
# The accuracy is 0.100000
#
# step: 8610
# The loss is nan
# The accuracy is 0.100000
#
# step: 8620
# The loss is nan
# The accuracy is 0.100000
#
# step: 8630
# The loss is nan
# The accuracy is 0.000000
#
# step: 8640
# The loss is nan
# The accuracy is 0.000000
#
# step: 8650
# The loss is nan
# The accuracy is 0.000000
#
# step: 8660
# The loss is nan
# The accuracy is 0.100000
#
# step: 8670
# The loss is nan
# The accuracy is 0.100000
#
# step: 8680
# The loss is nan
# The accuracy is 0.000000
#
# step: 8690
# The loss is nan
# The accuracy is 0.300000
#
# step: 8700
# The loss is nan
# The accuracy is 0.000000
#
# step: 8710
# The loss is nan
# The accuracy is 0.000000
#
# step: 8720
# The loss is nan
# The accuracy is 0.300000
#
# step: 8730
# The loss is nan
# The accuracy is 0.200000
#
# step: 8740
# The loss is nan
# The accuracy is 0.100000
#
# step: 8750
# The loss is nan
# The accuracy is 0.000000
#
# step: 8760
# The loss is nan
# The accuracy is 0.200000
#
# step: 8770
# The loss is nan
# The accuracy is 0.300000
#
# step: 8780
# The loss is nan
# The accuracy is 0.000000
#
# step: 8790
# The loss is nan
# The accuracy is 0.200000
#
# step: 8800
# The loss is nan
# The accuracy is 0.100000
#
# step: 8810
# The loss is nan
# The accuracy is 0.100000
#
# step: 8820
# The loss is nan
# The accuracy is 0.300000
#
# step: 8830
# The loss is nan
# The accuracy is 0.000000
#
# step: 8840
# The loss is nan
# The accuracy is 0.100000
#
# step: 8850
# The loss is nan
# The accuracy is 0.100000
#
# step: 8860
# The loss is nan
# The accuracy is 0.000000
#
# step: 8870
# The loss is nan
# The accuracy is 0.100000
#
# step: 8880
# The loss is nan
# The accuracy is 0.000000
#
# step: 8890
# The loss is nan
# The accuracy is 0.200000
#
# step: 8900
# The loss is nan
# The accuracy is 0.000000
#
# step: 8910
# The loss is nan
# The accuracy is 0.000000
#
# step: 8920
# The loss is nan
# The accuracy is 0.200000
#
# step: 8930
# The loss is nan
# The accuracy is 0.200000
#
# step: 8940
# The loss is nan
# The accuracy is 0.200000
#
# ...
#
# step: 57040
# The loss is nan
# The accuracy is 0.200000
#
# step: 57050
# The loss is nan
# The accuracy is 0.000000
#
# step: 57060
# The loss is nan
# The accuracy is 0.100000
#
# step: 57070
# The loss is nan
# The accuracy is 0.100000
#
# step: 57080
# The loss is nan
# The accuracy is 0.300000
#
# step: 57090
# The loss is nan
# The accuracy is 0.000000
#
# step: 57100
# The loss is nan
# The accuracy is 0.200000
#
# step: 57110
# The loss is nan
# The accuracy is 0.300000
#
# step: 57120
# The loss is nan
# The accuracy is 0.000000
#
# step: 57130
# The loss is nan
# The accuracy is 0.100000
#
# step: 57140
# The loss is nan
# The accuracy is 0.000000
#
# step: 57150
# The loss is nan
# The accuracy is 0.000000
#
# step: 57160
# The loss is nan
# The accuracy is 0.300000
#
# step: 57170
# The loss is nan
# The accuracy is 0.100000
#
# step: 57180
# The loss is nan
# The accuracy is 0.100000
#
# step: 57190
# The loss is nan
# The accuracy is 0.200000
#
# step: 57200
# The loss is nan
# The accuracy is 0.100000
#
# step: 57210
# The loss is nan
# The accuracy is 0.100000
#
# step: 57220
# The loss is nan
# The accuracy is 0.000000
#
# step: 57230
# The loss is nan
# The accuracy is 0.100000
#
# step: 57240
# The loss is nan
# The accuracy is 0.100000
#
# step: 57250
# The loss is nan
# The accuracy is 0.100000
#
# step: 57260
# The loss is nan
# The accuracy is 0.000000
#
# step: 57270
# The loss is nan
# The accuracy is 0.100000
#
# step: 57280
# The loss is nan
# The accuracy is 0.300000
#
# step: 57290
# The loss is nan
# The accuracy is 0.200000
#
# step: 57300
# The loss is nan
# The accuracy is 0.200000
#
# step: 57310
# The loss is nan
# The accuracy is 0.100000
#
# step: 57320
# The loss is nan
# The accuracy is 0.100000
#
# step: 57330
# The loss is nan
# The accuracy is 0.100000
#
# step: 57340
# The loss is nan
# The accuracy is 0.100000
#
# step: 57350
# The loss is nan
# The accuracy is 0.000000
#
# step: 57360
# The loss is nan
# The accuracy is 0.200000
#
# step: 57370
# The loss is nan
# The accuracy is 0.100000
#
# step: 57380
# The loss is nan
# The accuracy is 0.100000
#
# step: 57390
# The loss is nan
# The accuracy is 0.300000
#
# step: 57400
# The loss is nan
# The accuracy is 0.000000
#
# step: 57410
# The loss is nan
# The accuracy is 0.200000
#
# step: 57420
# The loss is nan
# The accuracy is 0.300000
#
# step: 57430
# The loss is nan
# The accuracy is 0.100000
#
# step: 57440
# The loss is nan
# The accuracy is 0.100000
#
# step: 57450
# The loss is nan
# The accuracy is 0.100000
#
# step: 57460
# The loss is nan
# The accuracy is 0.000000
#
# step: 57470
# The loss is nan
# The accuracy is 0.100000
#
# step: 57480
# The loss is nan
# The accuracy is 0.100000
#
# step: 57490
# The loss is nan
# The accuracy is 0.000000
#
# step: 57500
# The loss is nan
# The accuracy is 0.000000
#
# step: 57510
# The loss is nan
# The accuracy is 0.200000
#
# step: 57520
# The loss is nan
# The accuracy is 0.200000
#
# step: 57530
# The loss is nan
# The accuracy is 0.200000
#
# step: 57540
# The loss is nan
# The accuracy is 0.000000
#
# step: 57550
# The loss is nan
# The accuracy is 0.200000
#
# step: 57560
# The loss is nan
# The accuracy is 0.100000
#
# step: 57570
# The loss is nan
# The accuracy is 0.000000
#
# step: 57580
# The loss is nan
# The accuracy is 0.000000
#
# step: 57590
# The loss is nan
# The accuracy is 0.300000
#
# step: 57600
# The loss is nan
# The accuracy is 0.100000
#
# step: 57610
# The loss is nan
# The accuracy is 0.100000
#
# step: 57620
# The loss is nan
# The accuracy is 0.000000
#
# step: 57630
# The loss is nan
# The accuracy is 0.100000
#
# step: 57640
# The loss is nan
# The accuracy is 0.100000
#
# step: 57650
# The loss is nan
# The accuracy is 0.200000
#
# step: 57660
# The loss is nan
# The accuracy is 0.200000
#
# step: 57670
# The loss is nan
# The accuracy is 0.100000
#
# step: 57680
# The loss is nan
# The accuracy is 0.000000
#
# step: 57690
# The loss is nan
# The accuracy is 0.100000
#
# step: 57700
# The loss is nan
# The accuracy is 0.200000
#
# step: 57710
# The loss is nan
# The accuracy is 0.000000
#
# step: 57720
# The loss is nan
# The accuracy is 0.200000
#
# step: 57730
# The loss is nan
# The accuracy is 0.100000
#
# step: 57740
# The loss is nan
# The accuracy is 0.100000
#
# step: 57750
# The loss is nan
# The accuracy is 0.300000
#
# step: 57760
# The loss is nan
# The accuracy is 0.000000
#
# step: 57770
# The loss is nan
# The accuracy is 0.000000
#
# step: 57780
# The loss is nan
# The accuracy is 0.000000
#
# step: 57790
# The loss is nan
# The accuracy is 0.000000
#
# step: 57800
# The loss is nan
# The accuracy is 0.000000
#
# step: 57810
# The loss is nan
# The accuracy is 0.000000
#
# step: 57820
# The loss is nan
# The accuracy is 0.200000
#
# step: 57830
# The loss is nan
# The accuracy is 0.000000
#
# step: 57840
# The loss is nan
# The accuracy is 0.000000
#
# step: 57850
# The loss is nan
# The accuracy is 0.100000
#
# step: 57860
# The loss is nan
# The accuracy is 0.300000
#
# step: 57870
# The loss is nan
# The accuracy is 0.000000
# step: 57880
# The loss is nan
# The accuracy is 0.000000
#
# step: 57890
# The loss is nan
# The accuracy is 0.100000
#
# step: 57900
# The loss is nan
# The accuracy is 0.300000
#
# step: 57910
# The loss is nan
# The accuracy is 0.000000
#
# step: 57920
# The loss is nan
# The accuracy is 0.000000
#
# step: 57930
# The loss is nan
# The accuracy is 0.100000
#
# step: 57940
# The loss is nan
# The accuracy is 0.200000
#
# step: 57950
# The loss is nan
# The accuracy is 0.200000
#
# step: 57960
# The loss is nan
# The accuracy is 0.100000
#
# step: 57970
# The loss is nan
# The accuracy is 0.000000
#
# step: 57980
# The loss is nan
# The accuracy is 0.200000
#
# step: 57990
# The loss is nan
# The accuracy is 0.100000
#
# step: 58000
# The loss is nan
# The accuracy is 0.300000
#
# step: 58010
# The loss is nan
# The accuracy is 0.000000
#
# step: 58020
# The loss is nan
# The accuracy is 0.000000
#
# step: 58030
# The loss is nan
# The accuracy is 0.000000
#
# step: 58040
# The loss is nan
# The accuracy is 0.100000
#
# step: 58050
# The loss is nan
# The accuracy is 0.000000
#
# step: 58060
# The loss is nan
# The accuracy is 0.100000
#
# step: 58070
# The loss is nan
# The accuracy is 0.100000
#
# step: 58080
# The loss is nan
# The accuracy is 0.100000
#
# step: 58090
# The loss is nan
# The accuracy is 0.000000
#
# step: 58100
# The loss is nan
# The accuracy is 0.100000
#
# step: 58110
# The loss is nan
# The accuracy is 0.200000
#
# step: 58120
# The loss is nan
# The accuracy is 0.100000
#
# step: 58130
# The loss is nan
# The accuracy is 0.000000
#
# step: 58140
# The loss is nan
# The accuracy is 0.100000
#
# step: 58150
# The loss is nan
# The accuracy is 0.000000
#
# step: 58160
# The loss is nan
# The accuracy is 0.100000
#
# step: 58170
# The loss is nan
# The accuracy is 0.100000
#
# step: 58180
# The loss is nan
# The accuracy is 0.000000
#
# step: 58190
# The loss is nan
# The accuracy is 0.100000
#
# step: 58200
# The loss is nan
# The accuracy is 0.100000
#
# step: 58210
# The loss is nan
# The accuracy is 0.200000
#
# step: 58220
# The loss is nan
# The accuracy is 0.000000
#
# step: 58230
# The loss is nan
# The accuracy is 0.000000
#
# step: 58240
# The loss is nan
# The accuracy is 0.000000
#
# step: 58250
# The loss is nan
# The accuracy is 0.100000
#
# step: 58260
# The loss is nan
# The accuracy is 0.200000
#
# step: 58270
# The loss is nan
# The accuracy is 0.200000
#
# step: 58280
# The loss is nan
# The accuracy is 0.000000
#
# step: 58290
# The loss is nan
# The accuracy is 0.100000
#
# step: 58300
# The loss is nan
# The accuracy is 0.000000
#
# step: 58310
# The loss is nan
# The accuracy is 0.100000
#
# step: 58320
# The loss is nan
# The accuracy is 0.200000
#
# step: 58330
# The loss is nan
# The accuracy is 0.100000
#
# step: 58340
# The loss is nan
# The accuracy is 0.200000
#
# step: 58350
# The loss is nan
# The accuracy is 0.200000
#
# step: 58360
# The loss is nan
# The accuracy is 0.100000
#
# step: 58370
# The loss is nan
# The accuracy is 0.000000
#
# step: 58380
# The loss is nan
# The accuracy is 0.100000
#
# step: 58390
# The loss is nan
# The accuracy is 0.000000
#
# step: 58400
# The loss is nan
# The accuracy is 0.100000
#
# step: 58410
# The loss is nan
# The accuracy is 0.000000
#
# step: 58420
# The loss is nan
# The accuracy is 0.000000
#
# step: 58430
# The loss is nan
# The accuracy is 0.200000
#
# step: 58440
# The loss is nan
# The accuracy is 0.200000
#
# step: 58450
# The loss is nan
# The accuracy is 0.100000
#
# step: 58460
# The loss is nan
# The accuracy is 0.000000
#
# step: 58470
# The loss is nan
# The accuracy is 0.100000
#
# step: 58480
# The loss is nan
# The accuracy is 0.000000
#
# step: 58490
# The loss is nan
# The accuracy is 0.100000
#
# step: 58500
# The loss is nan
# The accuracy is 0.200000
#
# step: 58510
# The loss is nan
# The accuracy is 0.000000
#
# step: 58520
# The loss is nan
# The accuracy is 0.100000
#
# step: 58530
# The loss is nan
# The accuracy is 0.200000
#
# step: 58540
# The loss is nan
# The accuracy is 0.000000
#
# step: 58550
# The loss is nan
# The accuracy is 0.000000
#
# step: 58560
# The loss is nan
# The accuracy is 0.100000
#
# step: 58570
# The loss is nan
# The accuracy is 0.000000
#
# step: 58580
# The loss is nan
# The accuracy is 0.100000
#
# step: 58590
# The loss is nan
# The accuracy is 0.100000
#
# step: 58600
# The loss is nan
# The accuracy is 0.000000
#
# step: 58610
# The loss is nan
# The accuracy is 0.100000
#
# step: 58620
# The loss is nan
# The accuracy is 0.100000
#
# step: 58630
# The loss is nan
# The accuracy is 0.000000
#
# step: 58640
# The loss is nan
# The accuracy is 0.000000
#
# step: 58650
# The loss is nan
# The accuracy is 0.200000
#
# step: 58660
# The loss is nan
# The accuracy is 0.000000
#
# step: 58670
# The loss is nan
# The accuracy is 0.000000
#
# step: 58680
# The loss is nan
# The accuracy is 0.000000
#
# step: 58690
# The loss is nan
# The accuracy is 0.000000
#
# step: 58700
# The loss is nan
# The accuracy is 0.100000
#
# step: 58710
# The loss is nan
# The accuracy is 0.100000
#
# step: 58720
# The loss is nan
# The accuracy is 0.000000
#
# step: 58730
# The loss is nan
# The accuracy is 0.100000
#
# step: 58740
# The loss is nan
# The accuracy is 0.100000
#
# step: 58750
# The loss is nan
# The accuracy is 0.300000
#
# step: 58760
# The loss is nan
# The accuracy is 0.000000
#
# step: 58770
# The loss is nan
# The accuracy is 0.200000
#
# step: 58780
# The loss is nan
# The accuracy is 0.200000
#
# step: 58790
# The loss is nan
# The accuracy is 0.100000
#
# step: 58800
# The loss is nan
# The accuracy is 0.200000
#
# step: 58810
# The loss is nan
# The accuracy is 0.200000
#
# step: 58820
# The loss is nan
# The accuracy is 0.100000
#
# step: 58830
# The loss is nan
# The accuracy is 0.100000
#
# step: 58840
# The loss is nan
# The accuracy is 0.000000
#
# step: 58850
# The loss is nan
# The accuracy is 0.000000
#
# step: 58860
# The loss is nan
# The accuracy is 0.200000
#
# step: 58870
# The loss is nan
# The accuracy is 0.100000
#
# step: 58880
# The loss is nan
# The accuracy is 0.200000
#
# step: 58890
# The loss is nan
# The accuracy is 0.100000
#
# step: 58900
# The loss is nan
# The accuracy is 0.000000
#
# step: 58910
# The loss is nan
# The accuracy is 0.000000
#
# step: 58920
# The loss is nan
# The accuracy is 0.200000
#
# step: 58930
# The loss is nan
# The accuracy is 0.100000
#
# step: 58940
# The loss is nan
# The accuracy is 0.100000
#
# step: 58950
# The loss is nan
# The accuracy is 0.200000
#
# step: 58960
# The loss is nan
# The accuracy is 0.000000
#
# step: 58970
# The loss is nan
# The accuracy is 0.100000
#
# step: 58980
# The loss is nan
# The accuracy is 0.100000
#
# step: 58990
# The loss is nan
# The accuracy is 0.100000
#
# step: 59000
# The loss is nan
# The accuracy is 0.400000
#
# step: 59010
# The loss is nan
# The accuracy is 0.100000
#
# step: 59020
# The loss is nan
# The accuracy is 0.100000
#
# step: 59030
# The loss is nan
# The accuracy is 0.200000
#
# step: 59040
# The loss is nan
# The accuracy is 0.200000
#
# step: 59050
# The loss is nan
# The accuracy is 0.100000
#
# step: 59060
# The loss is nan
# The accuracy is 0.000000
#
# step: 59070
# The loss is nan
# The accuracy is 0.000000
#
# step: 59080
# The loss is nan
# The accuracy is 0.200000
#
# step: 59090
# The loss is nan
# The accuracy is 0.000000
#
# step: 59100
# The loss is nan
# The accuracy is 0.300000
#
# step: 59110
# The loss is nan
# The accuracy is 0.100000
#
# step: 59120
# The loss is nan
# The accuracy is 0.000000
#
# step: 59130
# The loss is nan
# The accuracy is 0.000000
#
# step: 59140
# The loss is nan
# The accuracy is 0.100000
#
# step: 59150
# The loss is nan
# The accuracy is 0.000000
#
# step: 59160
# The loss is nan
# The accuracy is 0.000000
#
# step: 59170
# The loss is nan
# The accuracy is 0.000000
#
# step: 59180
# The loss is nan
# The accuracy is 0.100000
#
# step: 59190
# The loss is nan
# The accuracy is 0.000000
#
# step: 59200
# The loss is nan
# The accuracy is 0.200000
#
# step: 59210
# The loss is nan
# The accuracy is 0.100000
#
# step: 59220
# The loss is nan
# The accuracy is 0.100000
#
# step: 59230
# The loss is nan
# The accuracy is 0.300000
#
# step: 59240
# The loss is nan
# The accuracy is 0.100000
#
# step: 59250
# The loss is nan
# The accuracy is 0.000000
#
# step: 59260
# The loss is nan
# The accuracy is 0.100000
#
# step: 59270
# The loss is nan
# The accuracy is 0.000000
#
# step: 59280
# The loss is nan
# The accuracy is 0.000000
#
# step: 59290
# The loss is nan
# The accuracy is 0.200000
#
# step: 59300
# The loss is nan
# The accuracy is 0.000000
#
# step: 59310
# The loss is nan
# The accuracy is 0.000000
#
# step: 59320
# The loss is nan
# The accuracy is 0.200000
#
# step: 59330
# The loss is nan
# The accuracy is 0.100000
#
# step: 59340
# The loss is nan
# The accuracy is 0.000000
#
# step: 59350
# The loss is nan
# The accuracy is 0.000000
#
# step: 59360
# The loss is nan
# The accuracy is 0.000000
#
# step: 59370
# The loss is nan
# The accuracy is 0.100000
#
# step: 59380
# The loss is nan
# The accuracy is 0.200000
#
# step: 59390
# The loss is nan
# The accuracy is 0.100000
#
# step: 59400
# The loss is nan
# The accuracy is 0.000000
#
# step: 59410
# The loss is nan
# The accuracy is 0.000000
#
# step: 59420
# The loss is nan
# The accuracy is 0.200000
#
# step: 59430
# The loss is nan
# The accuracy is 0.100000
#
# step: 59440
# The loss is nan
# The accuracy is 0.100000
#
# step: 59450
# The loss is nan
# The accuracy is 0.100000
#
# step: 59460
# The loss is nan
# The accuracy is 0.000000
#
# step: 59470
# The loss is nan
# The accuracy is 0.100000
#
# step: 59480
# The loss is nan
# The accuracy is 0.000000
#
# step: 59490
# The loss is nan
# The accuracy is 0.100000
#
# step: 59500
# The loss is nan
# The accuracy is 0.000000
#
# step: 59510
# The loss is nan
# The accuracy is 0.200000
# step: 59520
# The loss is nan
# The accuracy is 0.100000
#
# step: 59530
# The loss is nan
# The accuracy is 0.000000
#
# step: 59540
# The loss is nan
# The accuracy is 0.200000
#
# step: 59550
# The loss is nan
# The accuracy is 0.100000
#
# step: 59560
# The loss is nan
# The accuracy is 0.000000
#
# step: 59570
# The loss is nan
# The accuracy is 0.000000
#
# step: 59580
# The loss is nan
# The accuracy is 0.000000
#
# step: 59590
# The loss is nan
# The accuracy is 0.100000
#
# step: 59600
# The loss is nan
# The accuracy is 0.000000
#
# step: 59610
# The loss is nan
# The accuracy is 0.300000
#
# step: 59620
# The loss is nan
# The accuracy is 0.000000
#
# step: 59630
# The loss is nan
# The accuracy is 0.000000
#
# step: 59640
# The loss is nan
# The accuracy is 0.100000
#
# step: 59650
# The loss is nan
# The accuracy is 0.000000
#
# step: 59660
# The loss is nan
# The accuracy is 0.100000
#
# step: 59670
# The loss is nan
# The accuracy is 0.200000
#
# step: 59680
# The loss is nan
# The accuracy is 0.000000
#
# step: 59690
# The loss is nan
# The accuracy is 0.000000
#
# step: 59700
# The loss is nan
# The accuracy is 0.100000
#
# step: 59710
# The loss is nan
# The accuracy is 0.000000
#
# step: 59720
# The loss is nan
# The accuracy is 0.000000
#
# step: 59730
# The loss is nan
# The accuracy is 0.200000
#
# step: 59740
# The loss is nan
# The accuracy is 0.100000
#
# step: 59750
# The loss is nan
# The accuracy is 0.200000
#
# step: 59760
# The loss is nan
# The accuracy is 0.000000
#
# step: 59770
# The loss is nan
# The accuracy is 0.200000
#
# step: 59780
# The loss is nan
# The accuracy is 0.100000
#
# step: 59790
# The loss is nan
# The accuracy is 0.100000
#
# step: 59800
# The loss is nan
# The accuracy is 0.000000
#
# step: 59810
# The loss is nan
# The accuracy is 0.000000
#
# step: 59820
# The loss is nan
# The accuracy is 0.200000
#
# step: 59830
# The loss is nan
# The accuracy is 0.000000
#
# step: 59840
# The loss is nan
# The accuracy is 0.100000
#
# step: 59850
# The loss is nan
# The accuracy is 0.100000
#
# step: 59860
# The loss is nan
# The accuracy is 0.000000
#
# step: 59870
# The loss is nan
# The accuracy is 0.000000
#
# step: 59880
# The loss is nan
# The accuracy is 0.000000
#
# step: 59890
# The loss is nan
# The accuracy is 0.000000
#
# step: 59900
# The loss is nan
# The accuracy is 0.000000
#
# step: 59910
# The loss is nan
# The accuracy is 0.000000
#
# step: 59920
# The loss is nan
# The accuracy is 0.100000
#
# step: 59930
# The loss is nan
# The accuracy is 0.200000
#
# step: 59940
# The loss is nan
# The accuracy is 0.200000
#
# step: 59950
# The loss is nan
# The accuracy is 0.100000
#
# step: 59960
# The loss is nan
# The accuracy is 0.200000
#
# step: 59970
# The loss is nan
# The accuracy is 0.200000
#
# step: 59980
# The loss is nan
# The accuracy is 0.300000
#
# step: 59990
# The loss is nan
# The accuracy is 0.300000

# %%
# pred_features=[]
# for data in pred_data:
# #     data=data.reshape(1,-1)
#     pred_features.append(data)
# pred_features = np.array(pred_features).squeeze()
# print(pred_features.shape)

equals=[]

for i in range(x_test.shape[0]):
#     print(i)
#     pred_A1=sigmoid(np.dot(pred_features[i],w_1) + b_1)
#     pred_A2=sigmoid(np.dot(pred_A1,w_2) + b_2)
#     pred_y_=sigmoid(np.dot(pred_A2,w) + b)
#     print(pred_y_)
# #     print(np.argmax(y_,axis=1))
    forward_cache,loss = forward_propagation(w_1,b_1,w_2,b_2,w,b,x_test[i], y_test_one_hot[i])
    
#     print(forward_cache['y_'])
#     print(loss)
    argmax_y=np.argmax(y_test_one_hot[i])
    argmax_y_=np.argmax(forward_cache['y_'])
    if argmax_y==argmax_y_:
        equals.append(1)
    else:
        equals.append(0)
accuracy=np.sum(equals)/len(equals)
print ("The loss is %f" % (np.mean(np.square(loss))))
print ("The accuracy is %f\n" % accuracy)
# Out:
# /home/xin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in maximum
#
# /home/xin/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# The loss is nan
# The accuracy is 0.098000
