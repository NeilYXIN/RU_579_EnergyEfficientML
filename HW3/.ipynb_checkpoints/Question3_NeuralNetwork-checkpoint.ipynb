# %%
import matplotlib.pyplot as plt
import math
import numpy as np  
import operator  
import datetime
import time

# %%
import pickle
def load():
    with open("mnist.pkl",'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]

# %%
def one_hot_encoder(labels, class_nums=10):
    one_hot=np.zeros([len(labels), class_nums])
    for i in range(len(labels)):
        one_hot[i][labels[i]] = 1
    return one_hot

# %%
x_train, y_train, x_test, y_test = load()
x_train=x_train
x_test=x_test

# %%
y_train_one_hot = one_hot_encoder(y_train)
y_test_one_hot = one_hot_encoder(y_test)

# %%
def relu(x):
    return np.maximum(x,0.0)
 
def softmax(x):
    exps = np.exp(x - np.max(x))
    return exps / np.sum(exps)
 
def d_relu(x):
    (len_x,len_y)=x.shape
    d_x = np.zeros([len_x,len_y])
    [inds_x,inds_y]=np.where(x>=0)
    inds = np.stack((inds_x,inds_y), axis=-1) 
    for ind in inds:
        d_x[ind[0],ind[1]] = 1
    return d_x

# %%
def next_batch(train_x, train_y, batch_size, counter):
    batch_x = []
    batch_y = []
    rand_indices = []
    if len(train_x)-np.sum(counter) <= batch_size:
        for i in range(len(counter)):
            if counter[i]==0:
                rand_indices.append(i)
                counter[i]=1
    else:      
        while len(rand_indices) != batch_size:
            tmp=np.random.randint(0,len(train_x) - 1)
            if counter[tmp]==1:
                continue
            else:
                rand_indices.append(tmp)
                counter[tmp]=1
#     print("rand indices" , rand_indices)
    for index in rand_indices:
        batch_x.append(train_x[index])
        batch_y.append(train_y[index])
    return np.array(batch_x), np.array(batch_y),counter

# %%
def initialize_variables(size):
    w=np.random.randn(size[0], size[1]) * 0.01
#     w=np.zeros([size[0], size[1]])
#     b=np.random.random([size[1]])
    b=np.zeros(size[1])
    return w,b

# %%
learning_rate=0.01

def forward_propagation(w_1,b_1,w_2,b_2,w,b,X,y):
    Z1=np.dot(X,w_1) + b_1
    A1=relu(Z1)
    Z2=np.dot(A1,w_2) + b_2
    A2=relu(Z2)
    Z3=np.dot(A2,w) + b
    y_=softmax(Z3)
    
    loss = np.square(y-y_).sum()/len(y)
    
    cache={'Z1':Z1, 'A1':A1, 'Z2':Z2, 'A2':A2, 'Z3':Z3,'y_':y_}
    return cache, loss


def back_propagation(forward_cache,w_1,w_2,w,b_1,b_2,b,x,y):
    dZ3 = forward_cache['y_']-y
    wT = np.transpose(w)
    dZ2 = np.dot(dZ3,wT)*d_relu(forward_cache['Z2'])
    
    w_2T=np.transpose(w_2)
    dZ1 = np.dot(dZ2,w_2T)*d_relu(forward_cache['Z1'])
    
    
    m = forward_cache['A2'].shape[1]
    A2T = np.transpose(forward_cache['A2'])
    dw = np.dot(A2T,dZ3)/m
    db = np.sum(dZ3, axis=1, keepdims= True)/m
    
    m = forward_cache['A1'].shape[1]
    A1T=np.transpose(forward_cache['A1'])
    dw_2=np.dot(A1T,dZ2)/m
    db_2 = np.sum(dZ3,axis=1, keepdims= True)/m
    
    
    xT = np.transpose(x)
    dw_1 = np.dot(xT,dZ1)/m
    db_1 = np.sum(dZ2, axis=1, keepdims= True)/m
    
    
    w_1=w_1-learning_rate*dw_1
    b_1=b_1-learning_rate*db_1
    
    w_2=w_2-learning_rate*dw_2
    b_2=b_2-learning_rate*db_2
    
    w=w-learning_rate*dw
    b=b-learning_rate*b
    
    return w_1,b_1,w_2,b_2,w,b

# %%
print(y_train_one_hot.shape)
# Out:
# (60000, 10)

# %%
num_hidden_untis_one=200
num_hidden_units_two=50
n_dim = x_train.shape[1]
# sd = 1/np.sqrt(n_dim)

# index=0
# X=np.array(features[index])
# y=np.array(train_labels[index])
# print(X)
# print(y)


w_1,b_1=initialize_variables([x_train.shape[1], num_hidden_untis_one])

w_2,b_2=initialize_variables([num_hidden_untis_one, num_hidden_units_two])

w,b=initialize_variables([num_hidden_units_two, y_train_one_hot.shape[1]])

# learning rate, max iteration
num_epochs = 1
batch_size = 1
starttime = datetime.datetime.now()

for i in range(num_epochs): 
    print("epoch", i)
    counter=np.zeros(x_train.shape[0])
    step=0
    while np.sum(counter) < len(x_train):
        input_x,y,counter = next_batch(x_train, y_train_one_hot, batch_size, counter)
    #     input_x=x_train
    #     y=y_train_one_hot
        forward_cache,loss = forward_propagation(w_1,b_1,w_2,b_2,w,b,input_x, y)

        if step % 100 == 0:
            print('step:',step)
    #         print(forward_cache['y_'])
    #         print(y)
            argmax_y=np.argmax(y,axis=1)
            argmax_y_=np.argmax(forward_cache['y_'],axis=1)
            equals=[]
            for i in range(len(argmax_y)):
                if argmax_y[i]==argmax_y_[i]:
                    equals.append(1)
                else:
                    equals.append(0)
            accuracy=np.sum(equals)/len(equals)
            print ("The loss is %f" % (np.mean(np.square(loss))))
            print ("The accuracy is %f\n" % accuracy)

            #print output_error.tolist()
    #         continue
        w_1,b_1,w_2,b_2,w,b=back_propagation(forward_cache,w_1,w_2,w,b_1,b_2,b,input_x,y)
        step+=1
endtime = datetime.datetime.now()
print ("Training Time:", (endtime - starttime).seconds,'s')
# Out:
# epoch 0
# step: 0
# The loss is 0.855171
# The accuracy is 0.000000
#
# step: 100
# The loss is 0.811165
# The accuracy is 0.000000
#
# step: 200
# The loss is 0.791162
# The accuracy is 1.000000
#
# step: 300
# The loss is 0.843927
# The accuracy is 0.000000
#
# step: 400
# The loss is 0.762838
# The accuracy is 0.000000
#
# step: 500
# The loss is 0.799079
# The accuracy is 0.000000
#
# step: 600
# The loss is 0.742562
# The accuracy is 0.000000
#
# step: 700
# The loss is 0.728255
# The accuracy is 1.000000
#
# step: 800
# The loss is 0.860289
# The accuracy is 0.000000
#
# step: 900
# The loss is 0.623647
# The accuracy is 1.000000
#
# step: 1000
# The loss is 0.413389
# The accuracy is 1.000000
#
# step: 1100
# The loss is 0.367148
# The accuracy is 1.000000
#
# step: 1200
# The loss is 0.992636
# The accuracy is 0.000000
#
# step: 1300
# The loss is 0.791447
# The accuracy is 0.000000
#
# step: 1400
# The loss is 0.700538
# The accuracy is 0.000000
#
# step: 1500
# The loss is 0.007534
# The accuracy is 1.000000
#
# step: 1600
# The loss is 0.000125
# The accuracy is 1.000000
#
# step: 1700
# The loss is 0.367836
# The accuracy is 1.000000
#
# step: 1800
# The loss is 0.037476
# The accuracy is 1.000000
#
# step: 1900
# The loss is 1.102506
# The accuracy is 0.000000
#
# step: 2000
# The loss is 0.317901
# The accuracy is 0.000000
#
# step: 2100
# The loss is 0.000007
# The accuracy is 1.000000
#
# step: 2200
# The loss is 0.073904
# The accuracy is 1.000000
#
# step: 2300
# The loss is 0.003190
# The accuracy is 1.000000
#
# step: 2400
# The loss is 1.189111
# The accuracy is 0.000000
#
# step: 2500
# The loss is 0.172125
# The accuracy is 1.000000
#
# step: 2600
# The loss is 0.141428
# The accuracy is 1.000000
#
# step: 2700
# The loss is 1.482758
# The accuracy is 0.000000
#
# step: 2800
# The loss is 0.548679
# The accuracy is 1.000000
#
# step: 2900
# The loss is 0.439964
# The accuracy is 1.000000
#
# step: 3000
# The loss is 0.000094
# The accuracy is 1.000000
#
# step: 3100
# The loss is 1.891472
# The accuracy is 0.000000
#
# step: 3200
# The loss is 0.325960
# The accuracy is 0.000000
#
# step: 3300
# The loss is 1.387076
# The accuracy is 0.000000
#
# step: 3400
# The loss is 0.080386
# The accuracy is 1.000000
#
# step: 3500
# The loss is 0.023423
# The accuracy is 1.000000
#
# step: 3600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 3700
# The loss is 0.089929
# The accuracy is 1.000000
#
# step: 3800
# The loss is 0.000020
# The accuracy is 1.000000
#
# step: 3900
# The loss is 0.062774
# The accuracy is 1.000000
#
# step: 4000
# The loss is 0.442412
# The accuracy is 0.000000
#
# step: 4100
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 4200
# The loss is 0.033340
# The accuracy is 1.000000
#
# step: 4300
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 4400
# The loss is 0.000036
# The accuracy is 1.000000
#
# step: 4500
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 4600
# The loss is 0.002003
# The accuracy is 1.000000
#
# step: 4700
# The loss is 0.000016
# The accuracy is 1.000000
#
# step: 4800
# The loss is 0.449233
# The accuracy is 0.000000
#
# step: 4900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 5000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 5100
# The loss is 0.050760
# The accuracy is 1.000000
#
# step: 5200
# The loss is 2.651832
# The accuracy is 0.000000
#
# step: 5300
# The loss is 0.000038
# The accuracy is 1.000000
#
# step: 5400
# The loss is 0.000016
# The accuracy is 1.000000
#
# step: 5500
# The loss is 0.006191
# The accuracy is 1.000000
#
# step: 5600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 5700
# The loss is 1.352980
# The accuracy is 0.000000
#
# step: 5800
# The loss is 0.000265
# The accuracy is 1.000000
#
# step: 5900
# The loss is 0.000840
# The accuracy is 1.000000
#
# step: 6000
# The loss is 0.001321
# The accuracy is 1.000000
#
# step: 6100
# The loss is 1.227184
# The accuracy is 0.000000
#
# step: 6200
# The loss is 0.000003
# The accuracy is 1.000000
#
# step: 6300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 6400
# The loss is 0.525762
# The accuracy is 0.000000
#
# step: 6500
# The loss is 0.005030
# The accuracy is 1.000000
#
# step: 6600
# The loss is 0.488698
# The accuracy is 0.000000
#
# step: 6700
# The loss is 0.000053
# The accuracy is 1.000000
#
# step: 6800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 6900
# The loss is 0.000262
# The accuracy is 1.000000
#
# step: 7000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 7100
# The loss is 0.002684
# The accuracy is 1.000000
#
# step: 7200
# The loss is 1.802946
# The accuracy is 0.000000
#
# step: 7300
# The loss is 0.000094
# The accuracy is 1.000000
#
# step: 7400
# The loss is 0.065290
# The accuracy is 1.000000
#
# step: 7500
# The loss is 0.000515
# The accuracy is 1.000000
#
# step: 7600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 7700
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 7800
# The loss is 0.019367
# The accuracy is 1.000000
#
# step: 7900
# The loss is 0.024973
# The accuracy is 1.000000
#
# step: 8000
# The loss is 1.343932
# The accuracy is 0.000000
#
# step: 8100
# The loss is 0.000020
# The accuracy is 1.000000
#
# step: 8200
# The loss is 0.001728
# The accuracy is 1.000000
#
# step: 8300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 8400
# The loss is 0.000066
# The accuracy is 1.000000
#
# step: 8500
# The loss is 3.169646
# The accuracy is 0.000000
#
# step: 8600
# The loss is 0.133501
# The accuracy is 1.000000
#
# step: 8700
# The loss is 0.000030
# The accuracy is 1.000000
#
# step: 8800
# The loss is 0.199479
# The accuracy is 1.000000
#
# step: 8900
# The loss is 0.006723
# The accuracy is 1.000000
#
# step: 9000
# The loss is 0.000083
# The accuracy is 1.000000
#
# step: 9100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 9200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 9300
# The loss is 0.000088
# The accuracy is 1.000000
#
# step: 9400
# The loss is 0.808281
# The accuracy is 0.000000
#
# step: 9500
# The loss is 3.686745
# The accuracy is 0.000000
#
# step: 9600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 9700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 9800
# The loss is 0.726191
# The accuracy is 0.000000
#
# step: 9900
# The loss is 0.000062
# The accuracy is 1.000000
#
# step: 10000
# The loss is 0.000964
# The accuracy is 1.000000
#
# step: 10100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 10200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 10300
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 10400
# The loss is 0.888708
# The accuracy is 0.000000
#
# step: 10500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 10600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 10700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 10800
# The loss is 0.000208
# The accuracy is 1.000000
#
# step: 10900
# The loss is 0.006200
# The accuracy is 1.000000
#
# step: 11000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 11100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 11200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 11300
# The loss is 0.000044
# The accuracy is 1.000000
#
# step: 11400
# The loss is 1.356451
# The accuracy is 0.000000
#
# step: 11500
# The loss is 0.029088
# The accuracy is 1.000000
#
# step: 11600
# The loss is 1.665451
# The accuracy is 0.000000
#
# step: 11700
# The loss is 0.000248
# The accuracy is 1.000000
#
# step: 11800
# The loss is 0.000008
# The accuracy is 1.000000
#
# step: 11900
# The loss is 0.000003
# The accuracy is 1.000000
#
# step: 12000
# The loss is 1.801818
# The accuracy is 0.000000
#
# step: 12100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 12200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 12300
# The loss is 0.393438
# The accuracy is 1.000000
#
# step: 12400
# The loss is 0.006348
# The accuracy is 1.000000
#
# step: 12500
# The loss is 0.000393
# The accuracy is 1.000000
#
# step: 12600
# The loss is 0.166227
# The accuracy is 1.000000
#
# step: 12700
# The loss is 0.000007
# The accuracy is 1.000000
#
# step: 12800
# The loss is 0.200474
# The accuracy is 1.000000
#
# step: 12900
# The loss is 0.000250
# The accuracy is 1.000000
#
# step: 13000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 13100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 13200
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 13300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 13400
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 13500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 13600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 13700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 13800
# The loss is 0.000005
# The accuracy is 1.000000
#
# step: 13900
# The loss is 0.000019
# The accuracy is 1.000000
#
# step: 14000
# The loss is 0.000002
# The accuracy is 1.000000
# step: 14100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 14200
# The loss is 0.000797
# The accuracy is 1.000000
#
# step: 14300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 14400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 14500
# The loss is 0.000368
# The accuracy is 1.000000
#
# step: 14600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 14700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 14800
# The loss is 0.000071
# The accuracy is 1.000000
#
# step: 14900
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 15000
# The loss is 0.012713
# The accuracy is 1.000000
#
# step: 15100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 15200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 15300
# The loss is 0.000072
# The accuracy is 1.000000
#
# step: 15400
# The loss is 0.004303
# The accuracy is 1.000000
#
# step: 15500
# The loss is 0.016781
# The accuracy is 1.000000
#
# step: 15600
# The loss is 0.000004
# The accuracy is 1.000000
#
# step: 15700
# The loss is 0.000003
# The accuracy is 1.000000
#
# step: 15800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 15900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 16000
# The loss is 0.396492
# The accuracy is 0.000000
#
# step: 16100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 16200
# The loss is 0.000629
# The accuracy is 1.000000
#
# step: 16300
# The loss is 0.000101
# The accuracy is 1.000000
#
# step: 16400
# The loss is 0.496269
# The accuracy is 1.000000
#
# step: 16500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 16600
# The loss is 0.000004
# The accuracy is 1.000000
#
# step: 16700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 16800
# The loss is 0.000554
# The accuracy is 1.000000
#
# step: 16900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 17000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 17100
# The loss is 1.364165
# The accuracy is 0.000000
#
# step: 17200
# The loss is 0.000553
# The accuracy is 1.000000
#
# step: 17300
# The loss is 0.000004
# The accuracy is 1.000000
#
# step: 17400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 17500
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 17600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 17700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 17800
# The loss is 0.570596
# The accuracy is 0.000000
#
# step: 17900
# The loss is 0.008772
# The accuracy is 1.000000
#
# step: 18000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 18100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 18200
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 18300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 18400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 18500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 18600
# The loss is 0.026685
# The accuracy is 1.000000
#
# step: 18700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 18800
# The loss is 0.262767
# The accuracy is 1.000000
#
# step: 18900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 19000
# The loss is 0.000254
# The accuracy is 1.000000
#
# step: 19100
# The loss is 0.216216
# The accuracy is 1.000000
#
# step: 19200
# The loss is 0.000011
# The accuracy is 1.000000
#
# step: 19300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 19400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 19500
# The loss is 0.000812
# The accuracy is 1.000000
#
# step: 19600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 19700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 19800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 19900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 20000
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 20100
# The loss is 0.000026
# The accuracy is 1.000000
#
# step: 20200
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 20300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 20400
# The loss is 0.000003
# The accuracy is 1.000000
#
# step: 20500
# The loss is 0.207135
# The accuracy is 1.000000
#
# step: 20600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 20700
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 20800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 20900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 21000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 21100
# The loss is 0.002149
# The accuracy is 1.000000
#
# step: 21200
# The loss is 0.000308
# The accuracy is 1.000000
#
# step: 21300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 21400
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 21500
# The loss is 0.000158
# The accuracy is 1.000000
#
# step: 21600
# The loss is 0.000082
# The accuracy is 1.000000
#
# step: 21700
# The loss is 0.468532
# The accuracy is 0.000000
#
# step: 21800
# The loss is 0.024591
# The accuracy is 1.000000
#
# step: 21900
# The loss is 0.000011
# The accuracy is 1.000000
#
# step: 22000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 22100
# The loss is 0.000050
# The accuracy is 1.000000
#
# step: 22200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 22300
# The loss is 0.000069
# The accuracy is 1.000000
#
# step: 22400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 22500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 22600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 22700
# The loss is 2.906074
# The accuracy is 0.000000
#
# step: 22800
# The loss is 0.911383
# The accuracy is 0.000000
#
# step: 22900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 23000
# The loss is 0.898608
# The accuracy is 0.000000
#
# step: 23100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 23200
# The loss is 1.290503
# The accuracy is 0.000000
#
# step: 23300
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 23400
# The loss is 0.000146
# The accuracy is 1.000000
#
# step: 23500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 23600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 23700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 23800
# The loss is 0.000005
# The accuracy is 1.000000
#
# step: 23900
# The loss is 0.000636
# The accuracy is 1.000000
#
# step: 24000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 24100
# The loss is 0.060966
# The accuracy is 1.000000
#
# step: 24200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 24300
# The loss is 0.001094
# The accuracy is 1.000000
#
# step: 24400
# The loss is 0.334260
# The accuracy is 0.000000
#
# step: 24500
# The loss is 1.918782
# The accuracy is 0.000000
#
# step: 24600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 24700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 24800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 24900
# The loss is 0.137048
# The accuracy is 1.000000
#
# step: 25000
# The loss is 0.000197
# The accuracy is 1.000000
#
# step: 25100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 25200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 25300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 25400
# The loss is 0.000027
# The accuracy is 1.000000
#
# step: 25500
# The loss is 0.000008
# The accuracy is 1.000000
#
# step: 25600
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 25700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 25800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 25900
# The loss is 0.000063
# The accuracy is 1.000000
#
# step: 26000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 26100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 26200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 26300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 26400
# The loss is 0.800720
# The accuracy is 0.000000
#
# step: 26500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 26600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 26700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 26800
# The loss is 0.000975
# The accuracy is 1.000000
#
# step: 26900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 27000
# The loss is 0.000059
# The accuracy is 1.000000
#
# step: 27100
# The loss is 1.752505
# The accuracy is 0.000000
#
# step: 27200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 27300
# The loss is 0.000007
# The accuracy is 1.000000
#
# step: 27400
# The loss is 0.388110
# The accuracy is 0.000000
#
# step: 27500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 27600
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 27700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 27800
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 27900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 28000
# The loss is 0.000000
# The accuracy is 1.000000
# step: 28100
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 28200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 28300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 28400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 28500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 28600
# The loss is 0.003060
# The accuracy is 1.000000
#
# step: 28700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 28800
# The loss is 0.000046
# The accuracy is 1.000000
#
# step: 28900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 29000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 29100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 29200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 29300
# The loss is 0.000004
# The accuracy is 1.000000
#
# step: 29400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 29500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 29600
# The loss is 0.024105
# The accuracy is 1.000000
#
# step: 29700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 29800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 29900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 30000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 30100
# The loss is 0.003016
# The accuracy is 1.000000
#
# step: 30200
# The loss is 0.000019
# The accuracy is 1.000000
#
# step: 30300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 30400
# The loss is 0.036091
# The accuracy is 1.000000
#
# step: 30500
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 30600
# The loss is 0.410062
# The accuracy is 0.000000
#
# step: 30700
# The loss is 1.777582
# The accuracy is 0.000000
#
# step: 30800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 30900
# The loss is 0.000053
# The accuracy is 1.000000
#
# step: 31000
# The loss is 0.001768
# The accuracy is 1.000000
#
# step: 31100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 31200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 31300
# The loss is 3.451462
# The accuracy is 0.000000
#
# step: 31400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 31500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 31600
# The loss is 0.000049
# The accuracy is 1.000000
#
# step: 31700
# The loss is 0.000055
# The accuracy is 1.000000
#
# step: 31800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 31900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 32000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 32100
# The loss is 0.006277
# The accuracy is 1.000000
#
# step: 32200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 32300
# The loss is 3.241016
# The accuracy is 0.000000
#
# step: 32400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 32500
# The loss is 3.020561
# The accuracy is 0.000000
#
# step: 32600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 32700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 32800
# The loss is 0.000420
# The accuracy is 1.000000
#
# step: 32900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 33000
# The loss is 0.002552
# The accuracy is 1.000000
#
# step: 33100
# The loss is 0.000599
# The accuracy is 1.000000
#
# step: 33200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 33300
# The loss is 0.000020
# The accuracy is 1.000000
#
# step: 33400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 33500
# The loss is 0.000022
# The accuracy is 1.000000
#
# step: 33600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 33700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 33800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 33900
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 34000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 34100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 34200
# The loss is 0.004447
# The accuracy is 1.000000
#
# step: 34300
# The loss is 0.000016
# The accuracy is 1.000000
#
# step: 34400
# The loss is 0.000011
# The accuracy is 1.000000
#
# step: 34500
# The loss is 0.018829
# The accuracy is 1.000000
#
# step: 34600
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 34700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 34800
# The loss is 0.061032
# The accuracy is 1.000000
#
# step: 34900
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 35000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 35100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 35200
# The loss is 0.000693
# The accuracy is 1.000000
#
# step: 35300
# The loss is 0.000004
# The accuracy is 1.000000
#
# step: 35400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 35500
# The loss is 0.000021
# The accuracy is 1.000000
#
# step: 35600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 35700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 35800
# The loss is 0.000032
# The accuracy is 1.000000
#
# step: 35900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 36000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 36100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 36200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 36300
# The loss is 0.000039
# The accuracy is 1.000000
#
# step: 36400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 36500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 36600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 36700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 36800
# The loss is 2.818856
# The accuracy is 0.000000
#
# step: 36900
# The loss is 0.143893
# The accuracy is 1.000000
#
# step: 37000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 37100
# The loss is 0.000022
# The accuracy is 1.000000
#
# step: 37200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 37300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 37400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 37500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 37600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 37700
# The loss is 0.060072
# The accuracy is 1.000000
#
# step: 37800
# The loss is 0.000059
# The accuracy is 1.000000
#
# step: 37900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 38000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 38100
# The loss is 0.002793
# The accuracy is 1.000000
#
# step: 38200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 38300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 38400
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 38500
# The loss is 0.809346
# The accuracy is 0.000000
#
# step: 38600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 38700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 38800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 38900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 39000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 39100
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 39200
# The loss is 0.000211
# The accuracy is 1.000000
#
# step: 39300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 39400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 39500
# The loss is 1.066117
# The accuracy is 0.000000
#
# step: 39600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 39700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 39800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 39900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 40000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 40100
# The loss is 0.000020
# The accuracy is 1.000000
#
# step: 40200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 40300
# The loss is 0.000164
# The accuracy is 1.000000
#
# step: 40400
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 40500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 40600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 40700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 40800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 40900
# The loss is 0.073622
# The accuracy is 1.000000
#
# step: 41000
# The loss is 3.302819
# The accuracy is 0.000000
#
# step: 41100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 41200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 41300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 41400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 41500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 41600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 41700
# The loss is 0.000695
# The accuracy is 1.000000
#
# step: 41800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 41900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 42000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 42100
# The loss is 0.000000
# The accuracy is 1.000000
# step: 42200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 42300
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 42400
# The loss is 0.000501
# The accuracy is 1.000000
#
# step: 42500
# The loss is 0.651763
# The accuracy is 0.000000
#
# step: 42600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 42700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 42800
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 42900
# The loss is 0.008265
# The accuracy is 1.000000
#
# step: 43000
# The loss is 0.000012
# The accuracy is 1.000000
#
# step: 43100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 43200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 43300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 43400
# The loss is 0.000602
# The accuracy is 1.000000
#
# step: 43500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 43600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 43700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 43800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 43900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 44000
# The loss is 0.000006
# The accuracy is 1.000000
#
# step: 44100
# The loss is 0.000003
# The accuracy is 1.000000
#
# step: 44200
# The loss is 0.199253
# The accuracy is 1.000000
#
# step: 44300
# The loss is 0.001122
# The accuracy is 1.000000
#
# step: 44400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 44500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 44600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 44700
# The loss is 0.001090
# The accuracy is 1.000000
#
# step: 44800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 44900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 45000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 45100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 45200
# The loss is 0.012035
# The accuracy is 1.000000
#
# step: 45300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 45400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 45500
# The loss is 0.010715
# The accuracy is 1.000000
#
# step: 45600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 45700
# The loss is 0.030198
# The accuracy is 1.000000
#
# step: 45800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 45900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 46000
# The loss is 0.617017
# The accuracy is 0.000000
#
# step: 46100
# The loss is 0.000035
# The accuracy is 1.000000
#
# step: 46200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 46300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 46400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 46500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 46600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 46700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 46800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 46900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 47000
# The loss is 0.000009
# The accuracy is 1.000000
#
# step: 47100
# The loss is 3.648924
# The accuracy is 0.000000
#
# step: 47200
# The loss is 0.108226
# The accuracy is 1.000000
#
# step: 47300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 47400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 47500
# The loss is 0.000012
# The accuracy is 1.000000
#
# step: 47600
# The loss is 0.002314
# The accuracy is 1.000000
#
# step: 47700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 47800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 47900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 48000
# The loss is 0.325705
# The accuracy is 0.000000
#
# step: 48100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 48200
# The loss is 3.158264
# The accuracy is 0.000000
#
# step: 48300
# The loss is 0.000356
# The accuracy is 1.000000
#
# step: 48400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 48500
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 48600
# The loss is 0.580022
# The accuracy is 0.000000
#
# step: 48700
# The loss is 0.000036
# The accuracy is 1.000000
#
# step: 48800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 48900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 49000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 49100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 49200
# The loss is 0.000513
# The accuracy is 1.000000
#
# step: 49300
# The loss is 0.015400
# The accuracy is 1.000000
#
# step: 49400
# The loss is 0.012815
# The accuracy is 1.000000
#
# step: 49500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 49600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 49700
# The loss is 0.000512
# The accuracy is 1.000000
#
# step: 49800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 49900
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 50000
# The loss is 2.620530
# The accuracy is 0.000000
#
# step: 50100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 50200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 50300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 50400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 50500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 50600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 50700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 50800
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 50900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 51000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 51100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 51200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 51300
# The loss is 0.000082
# The accuracy is 1.000000
#
# step: 51400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 51500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 51600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 51700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 51800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 51900
# The loss is 1.914165
# The accuracy is 0.000000
#
# step: 52000
# The loss is 0.004360
# The accuracy is 1.000000
#
# step: 52100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 52200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 52300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 52400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 52500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 52600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 52700
# The loss is 0.000125
# The accuracy is 1.000000
#
# step: 52800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 52900
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 53000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 53100
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 53200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 53300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 53400
# The loss is 0.000182
# The accuracy is 1.000000
#
# step: 53500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 53600
# The loss is 0.000217
# The accuracy is 1.000000
#
# step: 53700
# The loss is 0.000087
# The accuracy is 1.000000
#
# step: 53800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 53900
# The loss is 2.696702
# The accuracy is 0.000000
#
# step: 54000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 54100
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 54200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 54300
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 54400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 54500
# The loss is 0.005665
# The accuracy is 1.000000
#
# step: 54600
# The loss is 0.000002
# The accuracy is 1.000000
#
# step: 54700
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 54800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 54900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 55000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 55100
# The loss is 0.000644
# The accuracy is 1.000000
#
# step: 55200
# The loss is 0.019457
# The accuracy is 1.000000
#
# step: 55300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 55400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 55500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 55600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 55700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 55800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 55900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 56000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 56100
# The loss is 0.022129
# The accuracy is 1.000000
#
# step: 56200
# The loss is 0.000000
# The accuracy is 1.000000
# step: 56300
# The loss is 0.000030
# The accuracy is 1.000000
#
# step: 56400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 56500
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 56600
# The loss is 2.479365
# The accuracy is 0.000000
#
# step: 56700
# The loss is 0.000003
# The accuracy is 1.000000
#
# step: 56800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 56900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 57000
# The loss is 0.000012
# The accuracy is 1.000000
#
# step: 57100
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 57200
# The loss is 0.001018
# The accuracy is 1.000000
#
# step: 57300
# The loss is 0.000417
# The accuracy is 1.000000
#
# step: 57400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 57500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 57600
# The loss is 0.000196
# The accuracy is 1.000000
#
# step: 57700
# The loss is 0.331455
# The accuracy is 0.000000
#
# step: 57800
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 57900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 58000
# The loss is 0.000008
# The accuracy is 1.000000
#
# step: 58100
# The loss is 2.364544
# The accuracy is 0.000000
#
# step: 58200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 58300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 58400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 58500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 58600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 58700
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 58800
# The loss is 2.592618
# The accuracy is 0.000000
#
# step: 58900
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 59000
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 59100
# The loss is 0.005230
# The accuracy is 1.000000
#
# step: 59200
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 59300
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 59400
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 59500
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 59600
# The loss is 0.000000
# The accuracy is 1.000000
#
# step: 59700
# The loss is 0.000001
# The accuracy is 1.000000
#
# step: 59800
# The loss is 0.000106
# The accuracy is 1.000000
#
# step: 59900
# The loss is 0.000025
# The accuracy is 1.000000
#
# Training Time: 57 s

# %%
equals=[]

for i in range(x_test.shape[0]):
    forward_cache,loss = forward_propagation(w_1,b_1,w_2,b_2,w,b,x_test[i], y_test_one_hot[i])
    
#     print(forward_cache['y_'])
#     print(loss)
    argmax_y=np.argmax(y_test_one_hot[i])
    argmax_y_=np.argmax(forward_cache['y_'])
    if argmax_y==argmax_y_:
        equals.append(1)
    else:
        equals.append(0)
accuracy=np.sum(equals)/len(equals)
print ("The accuracy is %f\n" % accuracy)
# Out:
# The accuracy is 0.956000
